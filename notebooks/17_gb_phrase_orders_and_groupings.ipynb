# %% [markdown]
# # In this notebook
#
# We extend the latter half of notebook `16` for all 4 categories
# - as in notebook `16`
#     - we will derive a priority order of attributes
#     - we will find similar attributes using nearest neighbor search
# - in this notebook
#     - we will investigate what the similar phrases look like for each of our categories
#     - we will compute pos and neg sub-clusters
#         - we will estimate requisite probabilities
#     - we will store the top few similar meaning phrases in the database to serve out using the API

# %%
import pandas as pd
import json

pd.options.display.max_columns = 50
pd.options.display.max_colwidth = 200
pd.options.display.max_rows = 1000

# %%
from sqlalchemy import create_engine
import psycopg2 
import io

# %%
import os
import glob

# %%
import pickle

# %%
import numpy as np

# %% [markdown]
# # Load attributes from database

# %%
conn_string = 'postgresql+psycopg2://gabbydbuser:gabbyDBpass@localhost:5432/gabbyDB'

# %%
db = create_engine(conn_string)
conn = db.connect()

# %% [markdown]
# ### Getting key_phrases for product category

# %%
category='laptop'

# %%
key_phrases_query = \
    f'''
    SELECT KP.*, KS.n_reviews, KS.n_positive, KS.n_negative, KS.n_reviewers, KS.n_products
    FROM key_phrase_root KP, key_phrase_scores KS
    WHERE KP.key_phrase_id=KS.key_phrase_id
        and KP.category='{category}'
    '''
key_phrases = pd.read_sql(key_phrases_query, conn)

# %%
key_phrases.shape
# Out:
# (122630, 8)

# %%
key_phrases.head()
# Out:
#    key_phrase_id          phrase category  n_reviews  n_positive  n_negative  \
# 0         144553   security slot   laptop          7           4           3
# 1         144554   stable object   laptop          1           1           0
# 2         144558  computer equal   laptop          1           1           0
# 3         144562            slot   laptop        105          77          28
# 4         144565             bag   laptop       5430        4233        1197
#
#    n_reviewers  n_products
# 0            7           6
# 1            1           1
# 2            1           1
# 3           96          92
# 4         4860        1280

# %% [markdown]
# # Build a nearest neighbor model for phrases

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
from sklearn.neighbors import NearestNeighbors

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
# get spacy vectors for attributes

phrase_vectors = []

key_phrases['phrase'].progress_apply(lambda p: phrase_vectors.append(nlp(p).vector))
# Out:
#   0%|          | 0/122630 [00:00<?, ?it/s]
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 122625    None
# 122626    None
# 122627    None
# 122628    None
# 122629    None
# Name: phrase, Length: 122630, dtype: object

# %%
phrase_vectors_arr = np.vstack(phrase_vectors)

# %%
phrase_vectors_arr.shape
# Out:
# (122630, 96)

# %%
nn_model = NearestNeighbors()
nn_model.fit(phrase_vectors_arr)
# Out:
# NearestNeighbors()

# %%
q = nlp('Easy to set up').vector

# %%
nn_model.kneighbors([q], n_neighbors=10, return_distance=False)
# Out:
# array([[ 89841,  33468,  77052,  61944, 120615,  55651,  81724,  27307,
#          57891,  89597]])

# %% [markdown]
# ### checking out the NN model

# %%
def get_nearest_attributes(attribute, k=5):
    q = nlp(attribute).vector
    neighbors = nn_model.kneighbors([q], n_neighbors=k, return_distance=False)
    return neighbors[0]

# %%
qterms = ['Easy to set up', 'Quality display', 
            'Good color quality', 'Quality build', 
            'Sound quality', 
            'Minimal glare', 'Lightweight', 
            'Good viewing angles', 'Fast']

# %%
for q in qterms:
    print(q)
    neighbors =  get_nearest_attributes(q, 10)
    display(key_phrases.iloc[neighbors])
# 52954            1            1           1
# 56108            2            2           2
# 105640           0            1           1
# 76255            0            1           1
# 25313            0            1           1
# Sound quality
#         key_phrase_id                   phrase category  n_reviews  \
# 44432          199577   terrible sound quality   laptop          4
# 31033          146229      great sound quality   laptop         73
# 101885         184065        aceptable quality   laptop          1
# 5658           167062          plastic quality   laptop          1
# 45368          203212            geate quality   laptop          1
# 22358          234264     great quality laptop   laptop          6
# 19915          224375   great quality material   laptop          4
# 35486          164199     decent sound quality   laptop         16
# 121805         263937        big quality sound   laptop          1
# 93287          149398  excellent sound quality   laptop         18
#
#         n_positive  n_negative  n_reviewers  n_products
# 44432            1           3            4           3
# 31033           69           4           72          52
# 101885           0           1            1           1
# 5658             1           0            1           1
# 45368            1           0            1           1
# 22358            6           0            6           6
# 19915            4           0            4           4
# 35486           15           1           16          15
# 121805           1           0            1           1
# 93287           16           2           16          15
# Minimal glare
#         key_phrase_id                    phrase category  n_reviews  \
# 2403           154225         confidential work   laptop          1
# 77001          206889           crippling glare   laptop          1
# 50250          222382            minimal impact   laptop          1
# 36681          168804         positive feedback   laptop          4
# 42925          193678       positive experience   laptop          5
# 62620          149453            positive latch   laptop          1
# 105084         196969        upgradable storage   laptop          1
# 101811         183803  great batter replacement   laptop          1
# 81605          225222       great backup laptop   laptop          1
# 30371          266418              minimal work   laptop          1
#
#         n_positive  n_negative  n_reviewers  n_products
# 2403             1           0            1           1
# 77001            1           0            1           1
# 50250            0           1            1           1
# 36681            4           0            4           4
# 42925            4           1            5           5
# 62620            0           1            1           1
# 105084           1           0            1           1
# 101811           1           0            1           1
# 81605            1           0            1           1
# 30371            1           0            1           1
# Lightweight
#        key_phrase_id           phrase category  n_reviews  n_positive  \
# 52698         232055           m-5y10   laptop          2           2
# 68432         172377             mush   laptop          2           2
# 24163         241464         usb wifi   laptop          2           2
# 69055         174927         slimness   laptop          1           1
# 97796         167715             liar   laptop          1           0
# 63157         151455       deployment   laptop          3           3
# 33202         155098        acpro2000   laptop          6           6
# 70348         180274          150mbps   laptop          1           0
# 8178          177350        case wich   laptop          1           1
# 48743         216386  usb microsphone   laptop          1           0
#
#        n_negative  n_reviewers  n_products
# 52698           0            1           2
# 68432           0            2           2
# 24163           0            2           2
# 69055           0            1           1
# 97796           1            1           1
# 63157           0            3           3
# 33202           0            3           1
# 70348           1            1           1
# 8178            0            1           1
# 48743           1            1           1
# Good viewing angles
#         key_phrase_id                        phrase category  n_reviews  \
# 44473          199780           good viewing angles   laptop         13
# 12619          195079          great viewing angles   laptop          3
# 78593          213122       terrible viewing angles   laptop          2
# 99030          172625           poor viewing angles   laptop          8
# 83241          231544  disappointing viewing angles   laptop          1
# 110267         217987        amazing viewing angles   laptop          1
# 53640          235808     horizontal viewing angles   laptop          1
# 102349         185915       vertical viewing angles   laptop          1
# 55136          241795           wide viewing angles   laptop          1
# 93576          150593         great looking laptops   laptop          2
#
#         n_positive  n_negative  n_reviewers  n_products
# 44473           13           0           12          12
# 12619            3           0            3           3
# 78593            1           1            2           2
# 99030            4           4            8           8
# 83241            0           1            1           1
# 110267           0           1            1           1
# 53640            1           0            1           1
# 102349           1           0            1           1
# 55136            1           0            1           1
# 93576            2           0            1           2
# Fast
#         key_phrase_id           phrase category  n_reviews  n_positive  \
# 2298           153814             dual   laptop         18          12
# 26303          250025       fast clear   laptop          1           1
# 114947         237057  convenient fast   laptop          1           1
# 62015          146990             fast   laptop       1201        1127
# 119664         255461   separate upper   laptop          1           1
# 112908         228678    early present   laptop          1           1
# 5307           165656         fast new   laptop          1           1
# 61069          265575      steady loud   laptop          1           1
# 98752          171534          genuine   laptop         18          12
# 114192         233940   great separate   laptop          1           1
#
#         n_negative  n_reviewers  n_products
# 2298             6           18          18
# 26303            0            1           1
# 114947           0            1           1
# 62015           74         1141         787
# 119664           0            1           1
# 112908           0            1           1
# 5307             0            1           1
# 61069            0            1           1
# 98752            6           17          17
# 114192           0            1           1

# %% [markdown]
# # Trying with an unsupervised clustering model
#
# NOTE: we can't use generic unsupervised clustering methods because we don't know how many clusters can be there. Instead we do the following
#
#
# 1. we first find a 5 or 10 nearest neighbors for each attribute
#     - we then group/merge attributes together into clusters based on
#         - mean distance between neighbors across all neighbor sets
#
#
# 2.  we can cluster together, but also try to differentiate between positive and negative attribute clusters within the same semantic subspace
#     - e.g. q = "Good color quality"
#         - positive equivalent in subspace = "excellent color quality"
#         - negative equivalent in subspace = "poor color quality"
#     - OR:
#         - THIS [just looking at counts now] --> within each cluster, we subgroup based on probability of occurrence in positive or negative reviews

# %% [markdown]
# ## find nearest neighbors for each phrase

# %%
# keeping a list of attributes
attributes = key_phrases['phrase'].tolist()
key_phase_idx = key_phrases.index

# %%
key_phrases
# Out:
#         key_phrase_id                          phrase category  n_reviews  \
# 0              144553                   security slot   laptop          7
# 1              144554                   stable object   laptop          1
# 2              144558                  computer equal   laptop          1
# 3              144562                            slot   laptop        105
# 4              144565                             bag   laptop       5430
# ...               ...                             ...      ...        ...
# 122625         267162     steelseries flux headphones   laptop          1
# 122626         267165  normal operational temperature   laptop          1
# 122627         267166                good containment   laptop          1
# 122628         267168                      big crease   laptop          1
# 122629         267176              hp envy detachable   laptop          1
#
#         n_positive  n_negative  n_reviewers  n_products
# 0                4           3            7           6
# 1                1           0            1           1
# 2                1           0            1           1
# 3               77          28           96          92
# 4             4233        1197         4860        1280
# ...            ...         ...          ...         ...
# 122625           0           1            1           1
# 122626           0           1            1           1
# 122627           1           0            1           1
# 122628           0           1            1           1
# 122629           0           1            1           1
#
# [122630 rows x 8 columns]

# %%
import random

# %%
# for each phrase, for it's nearest neighbors, let's comput the inter-neighbor distance
# this is taking too long. We'll use a sample of 10000 to compute mean distance

SAMPLE_SIZE = 10000

all_clusters_mean_distance = 0 

for i in tqdm(random.sample(range(len(attributes)), SAMPLE_SIZE)):
    qvec = phrase_vectors_arr[i]
    distances, neighbors = nn_model.kneighbors([qvec], n_neighbors=10)
    all_clusters_mean_distance += distances[0].mean()

all_clusters_mean_distance /= SAMPLE_SIZE

all_clusters_mean_distance
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 2.9091489089727403

# %% [markdown]
# ## priority order for cluster generation
# - to generate clusters, we can't really go first come first serve, or random, because the clustering could then be inconsistent with reality
# - we can try to start with the phrases that occur most frequently in reviews, and go down the ranked list imposed by popularity
#     - this is also easier to explain

# %%
priority_order = key_phrases.sort_values(['n_reviewers', 'n_products'], ascending=False)['key_phrase_id'].index.tolist()

# %%
key_phrases.loc[priority_order[:10]]
# Out:
#        key_phrase_id    phrase category  n_reviews  n_positive  n_negative  \
# 30584         144570     stars   laptop      51760       47282        4478
# 61479         144571    laptop   laptop      20804       16423        4381
# 61494         144640     great   laptop      19998       18561        1437
# 30600         144613      good   laptop      13301       11120        2181
# 30634         144733     price   laptop       7220        6352         868
# 9             144592  computer   laptop       6938        4964        1974
# 92039         144581      nice   laptop       6092        5367         725
# 92137         144954   perfect   laptop       5898        5754         144
# 4             144565       bag   laptop       5430        4233        1197
# 117           145033   battery   laptop       4902        3298        1604
#
#        n_reviewers  n_products
# 30584        41423        7137
# 61479        18724        5210
# 61494        18242        5317
# 30600        11934        4466
# 30634         6799        2919
# 9             6435        2979
# 92039         5602        2628
# 92137         5505        2595
# 4             4860        1280
# 117           4686        1617

# %% [markdown]
# # Phrases close to the given terms

# %%
qphrases = {
    'laptop': ['Easy to set up', 'Quality display', 'Good color quality', 'Quality build', 'Sound quality', 'Easy to use', 'Minimal glare', 'Lightweight', 'Good viewing angles', 'Fast', 'long battery life', 'Noise level'],
    'monitor': ['Easy to set up', 'Quality display', 'Good color quality', 'Quality build', 'Sound quality', 'Easy to use', 'Minimal glare', 'Lightweight', 'Good viewing angles', 'Fast'],
    'headphone': ['Good sound quality', 'comfortable', 'long battery life', 'Easy to set up', 'Easy to use', 'Quality build', 'effective noise cancelling', 'Good bass', 'Call quality', 'Attractive'],
    'mouse': ['comfortable', 'long battery life', 'Easy to set up', 'Easy to use', 'Quality build', 'Attractive', 'Noise level', 'Easy to clean'],
    'tv': ['Easy to use', 'Easy to set up', 'Sound quality', 'Fast input response', 'lightweight', 'Attractive', 'quality build', 'lacks durability', 'speed', 'craftsmanship', 'camera quality', 'remote quality']
}

# %% [markdown]
# ### distance based clusters
# - we add those phrases to clusters that are within the average intra-cluster distance
# - THIS method is MORE efficient, and the terms seems quite nice

# %%
def nearest_neighbor_expansion(all_clusters_mean, max_neighbors, phrase_vectors_arr, attributes, nn, qphrase):
    # initialization
    qvec = nlp(qphrase).vector
    neighbor_distances, neighbor_indices = nn.kneighbors([qvec], n_neighbors=10)
    neighbor_indices = neighbor_indices[0]
    neighbor_distances =neighbor_distances[0]
    neighbor_attributes = [attributes[i] for i in neighbor_indices]
    cluster_mean_dist = neighbor_distances.mean()
    #print(cluster_mean_dist, all_clusters_mean)
    #print(neighbor_attributes)

    lc = 1      # increase in number of neighbors (10, 101, 10) to search for nearest neighor expansion
    while cluster_mean_dist < all_clusters_mean and lc < max_neighbors/lc + 1:
        # we need to find more neighbors for this phrase until the mean intra-cluster distance is greater than the mean
        q_idx = neighbor_indices
        #print(len(q_idx))
        qvec = phrase_vectors_arr[q_idx].mean(axis=0)
        #print(qvec)
        distances, neighbors = nn.kneighbors([qvec], n_neighbors=10*lc)
        distances = distances[0]
        neighbors = neighbors[0]
        for knn in range(len(neighbors)):
            #print(knn, neighbors[knn])
            if neighbors[knn] not in neighbor_indices:
                #print('added')
                neighbor_indices = np.append(neighbor_indices, neighbors[knn])
                neighbor_distances = np.append(neighbor_distances, distances[knn])
                neighbor_attributes.append(attributes[neighbors[knn]])
        cluster_mean_dist = neighbor_distances.mean()
        lc += 1

    mean_distance_occurrence_phrases = pd.DataFrame({
        'neighbor_idx': neighbor_indices,
        'neighbor_attr': neighbor_attributes,
        'neighbor_distances': neighbor_distances,
    })
    #print(cluster_mean_dist, all_clusters_mean, lc)
    return mean_distance_occurrence_phrases

# %%
qphrases[category]
# Out:
# ['Easy to set up',
#  'Quality display',
#  'Good color quality',
#  'Quality build',
#  'Sound quality',
#  'Easy to use',
#  'Minimal glare',
#  'Lightweight',
#  'Good viewing angles',
#  'Fast',
#  'long battery life',
#  'Noise level']

# %%
qphrase_neighbors = nearest_neighbor_expansion(all_clusters_mean_distance, 100, phrase_vectors_arr, attributes, nn_model, 'attractive')
qphrase_neighbors.sort_values('neighbor_distances')
# Out:
#    neighbor_idx  neighbor_attr  neighbor_distances
# 0         61848     attractive            0.000000
# 1          6453          angry            4.002241
# 2         16129          arive            4.006609
# 3            77      effective            4.076833
# 4         93059     impressive            4.078627
# 5         12175  imperceptible            4.086038
# 6        101601       playable            4.116393
# 7         71696  superstitious            4.210647
# 8         72831     changeable            4.311512
# 9         34964        evident            4.336577

# %%
qphrase_neighbors['key_phrase_id'] = qphrase_neighbors['neighbor_idx'].apply(lambda _row: key_phrases.iloc[_row]['key_phrase_id'])

# %%
qphrase_neighbors.merge(key_phrases, how='left', left_on='key_phrase_id', right_on='key_phrase_id').sort_values('n_reviews', ascending=False)
# Out:
#    neighbor_idx  neighbor_attr  neighbor_distances  key_phrase_id  \
# 3            77      effective            4.076833         144869
# 0         61848     attractive            0.000000         146276
# 4         93059     impressive            4.078627         148453
# 6        101601       playable            4.116393         183000
# 9         34964        evident            4.336577         162144
# 1          6453          angry            4.002241         170376
# 8         72831     changeable            4.311512         189947
# 2         16129          arive            4.006609         209153
# 5         12175  imperceptible            4.086038         193282
# 7         71696  superstitious            4.210647         185404
#
#           phrase category  n_reviews  n_positive  n_negative  n_reviewers  \
# 3      effective   laptop        230         210          20          222
# 0     attractive   laptop        228         206          22          216
# 4     impressive   laptop         90          76          14           88
# 6       playable   laptop          8           8           0            7
# 9        evident   laptop          7           5           2            7
# 1          angry   laptop          4           1           3            4
# 8     changeable   laptop          2           2           0            2
# 2          arive   laptop          1           1           0            1
# 5  imperceptible   laptop          1           1           0            1
# 7  superstitious   laptop          1           1           0            1
#
#    n_products
# 3         154
# 0         194
# 4          86
# 6           8
# 9           7
# 1           4
# 8           2
# 2           1
# 5           1
# 7           1

# %%
def get_similar_attributes(key_phrases, all_clusters_mean, max_neighbors, phrase_vectors_arr, attributes, nn_model, qphrase):
    qphrase_neighbors = nearest_neighbor_expansion(all_clusters_mean_distance, 100, phrase_vectors_arr, attributes, nn_model, qphrase)
    qphrase_neighbors['key_phrase_id'] = qphrase_neighbors['neighbor_idx'].apply(lambda _row: key_phrases.iloc[_row]['key_phrase_id'])
    qattr_nn = qphrase_neighbors.merge(key_phrases, how='left', left_on='key_phrase_id', right_on='key_phrase_id').sort_values('n_reviews', ascending=False)
    qattr_nn['qphrase'] = qphrase
    return qattr_nn

# %%
get_similar_attributes(key_phrases, all_clusters_mean_distance, 100, phrase_vectors_arr, attributes, nn_model, 'attractive')
# Out:
#    neighbor_idx  neighbor_attr  neighbor_distances  key_phrase_id  \
# 3            77      effective            4.076833         144869
# 0         61848     attractive            0.000000         146276
# 4         93059     impressive            4.078627         148453
# 6        101601       playable            4.116393         183000
# 9         34964        evident            4.336577         162144
# 1          6453          angry            4.002241         170376
# 8         72831     changeable            4.311512         189947
# 2         16129          arive            4.006609         209153
# 5         12175  imperceptible            4.086038         193282
# 7         71696  superstitious            4.210647         185404
#
#           phrase category  n_reviews  n_positive  n_negative  n_reviewers  \
# 3      effective   laptop        230         210          20          222
# 0     attractive   laptop        228         206          22          216
# 4     impressive   laptop         90          76          14           88
# 6       playable   laptop          8           8           0            7
# 9        evident   laptop          7           5           2            7
# 1          angry   laptop          4           1           3            4
# 8     changeable   laptop          2           2           0            2
# 2          arive   laptop          1           1           0            1
# 5  imperceptible   laptop          1           1           0            1
# 7  superstitious   laptop          1           1           0            1
#
#    n_products     qphrase
# 3         154  attractive
# 0         194  attractive
# 4          86  attractive
# 6           8  attractive
# 9           7  attractive
# 1           4  attractive
# 8           2  attractive
# 2           1  attractive
# 5           1  attractive
# 7           1  attractive

# %% [markdown]
# # Select curated terms
# 3 step process
# 1. pick those phrases that generate better looking terms; note the top ranking threshold for each phrase if needed
# 2. pick good looking ones from priority_order list; not the top ranking threshold for each phrase if needed
# 3. save the manually curated phrases and their respective top similar phrases into db

# %% [markdown]
# ### curating pre-selected attributes

# %%
curated_attributes = pd.DataFrame()

# %%
category, qphrases[category]
# Out:
# ('laptop',
#  ['Easy to set up',
#   'Quality display',
#   'Good color quality',
#   'Quality build',
#   'Sound quality',
#   'Easy to use',
#   'Minimal glare',
#   'Lightweight',
#   'Good viewing angles',
#   'Fast',
#   'long battery life',
#   'Noise level'])

# %% [markdown]
# ### curating priority ordered phrases

# %%
key_phrases.loc[priority_order[:25]]
# Out:
#        key_phrase_id         phrase category  n_reviews  n_positive  \
# 30584         144570          stars   laptop      51760       47282
# 61479         144571         laptop   laptop      20804       16423
# 61494         144640          great   laptop      19998       18561
# 30600         144613           good   laptop      13301       11120
# 30634         144733          price   laptop       7220        6352
# 9             144592       computer   laptop       6938        4964
# 92039         144581           nice   laptop       6092        5367
# 92137         144954        perfect   laptop       5898        5754
# 4             144565            bag   laptop       5430        4233
# 117           145033        battery   laptop       4902        3298
# 79             1           1  good product

# %%
#qattr_nn.sort_values('neighbor_distances')
qattr_nn[qattr_nn['n_reviews'] > 5]
# Out:
#      neighbor_idx       neighbor_attr  neighbor_distances  key_phrase_id  \
# 0           92149       sound quality            0.000000         145005
# 39           1948          sound card            2.591959         152305
# 46          34569        sound system            2.631195         160656
# 100         63622         laptop area            2.578620         153278
# 52          67878           sound bar            2.683086         170219
# 123         68895  good budget laptop            2.537901         174311
# 22          33722        sound volume            2.226938         157258
# 16          92767  sound reproduction            2.327458         147387
# 79          77937     excelent laptop            2.586962         210579
# 54          93372        laptop space            2.644377         149748
# 32           8741         sound level            2.539125         179547
# 29          98483        sound output            2.487013         170479
# 9           39419      signal quality            3.001112         179598
# 48           6382       sound clarity            2.645278         170025
#
#                  phrase category  n_reviews  n_positive  n_negative  \
# 0         sound quality   laptop        597         418         179
# 39           sound card   laptop         40          24          16
# 46         sound system   laptop         30          22           8
# 100         laptop area   laptop         25          17           8
# 52            sound bar   laptop         25          21           4
# 123  good budget laptop   laptop         13          10           3
# 22         sound volume   laptop          9           7           2
# 16   sound reproduction   laptop          9           6           3
# 79      excelent laptop   laptop          8           7           1
# 54         laptop space   laptop          8           8           0
# 32          sound level   laptop          7           5           2
# 29         sound output   laptop          7           7           0
# 9        signal quality   laptop          6           5           1
# 48        sound clarity   laptop          6           5           1
#
#      n_reviewers  n_products        qphrase
# 0            584         237  sound quality
# 39            38          30  sound quality
# 46            30          30  sound quality
# 100           24          23  sound quality
# 52            24          19  sound quality
# 123           13          13  sound quality
# 22             6           7  sound quality
# 16             9           7  sound quality
# 79             8           8  sound quality
# 54             7           7  sound quality
# 32             6           7  sound quality
# 29             7           6  sound quality
# 9              6           5  sound quality
# 48             6           6  sound quality

# %%
curated_attributes = pd.concat([curated_attributes, qattr_nn.head(3)])

# %%
curated_attributes.shape
# Out:
# (1073, 12)

# %%
curated_attributes.groupby('qphrase')['qphrase'].count()
# Out:
# qphrase
# easy setup            38
# easy use             102
# fast working          10
# good angle           128
# good camera            3
# good cooling           7
# good screen           56
# good sound           102
# good speakers        101
# great keyboard       102
# great laptop         104
# great price          111
# light Weight          10
# long battery life    101
# minimal glare         10
# screen quality        35
# sound quality         53
# Name: qphrase, dtype: int64

# %% [markdown]
# ## storing the manually curated terms in the database

# %%
curated_attributes.head()
# Out:
#     neighbor_idx     neighbor_attr  neighbor_distances  key_phrase_id  \
# 0          95823        easy setup            0.000000         159674
# 26         99876    easy transport            2.130146         176161
# 27         40288  easy transaction            2.133881         183187
# 28         70770      easy storage            2.202010         181876
# 36          6961       easy repair            2.251794         172588
#
#               phrase category  n_reviews  n_positive  n_negative  n_reviewers  \
# 0         easy setup   laptop         88          86           2           87
# 26    easy transport   laptop          2           1           1            2
# 27  easy transaction   laptop         11          11           0           10
# 28      easy storage   laptop          4           3           1            4
# 36       easy repair   laptop          5           5           0            5
#
#     n_products     qphrase
# 0           59  easy setup
# 26           2  easy setup
# 27          11  easy setup
# 28           4  easy setup
# 36           5  easy setup

# %%
curated_attributes.to_sql('shortlisted_attributes', con=conn, method='multi',
                            index=False, if_exists='append')
# Out:
# 1073

# %%
# API contenders
curated_attributes.sort_values('neighbor_distances').sort_values('n_reviews', ascending=False).groupby('qphrase')['phrase'].apply(list).reset_index()
# Out:
#               qphrase  \
# 0          easy setup
# 1            easy use
# 2        fast working
# 3          good angle
# 4         good camera
# 5        good cooling
# 6         good screen
# 7          good sound
# 8       good speakers
# 9      great keyboard
# 10       great laptop
# 11        great price
# 12       light Weight
# 13  long battery life
# 14      minimal glare
# 15     screen quality
# 16      sound quality
#
#                                                                                                                                                                                                      phrase
# 0   [easy installation, easy access, easy setup, good construction, easy replacement, great video quality, easy transaction, easy application, great construction, excellent video, easy process, easy c...
# 1   [light use, heavy use, normal use, regular use, personal use, constant use, good use, moderate use, continuous use, occasional use, easy use, casual use, great use, basic use, minimal use, actual ...
# 2                                                  [fast charging, fast typing, fast loading, fast scrolling, fast charging port, fast clicking, fast gaming, fast bshipping, fast starting, fast handling]
# 3   [good computer, good sleeve, good design, good service, good unit, good investment, protective sleeve, good company, good display, good video, good system, good angle, nice angle, perfect angle, g...
# 4                                                                                                                                                                  [great camera, good camera, nice camera]
# 5                                                                                                [heavy gaming, good lighting, great cooling, basic computing, great gaming, good cushioning, good cooling]
# 6   [great screen, blue screen, large screen, big screen, nice screen, glossy screen, good screen, black screen, new screen, beautiful screen, bright screen, small screen, original screen, excellent s...
# 7   [great sound, good sound, good sound quality, nice sound, great sound quality, decent sound, good charge, excellent sound, great laptop sleeve, big sound, good quality sound, nice laptop sleeve, b...
# 8   [great speakers, good speakers, nice speakers, small speakers, external speakers, internal speakers, decent speakers, cheap speakers, inexpensive speakers, awesome speakers, terrible speakers, old...
# 9   [great keyboard, good keyboard, nice keyboard, external keyboard, original keyboard, new keyboard, old keyboard, excellent keyboard, great replacement keyboard, small keyboard, bad keyboard, mecha...
# 10  [great laptop, good laptop, new laptop, nice laptop, old laptop, small laptop, decent laptop, large laptop, powerful laptop, fantastic laptop, cheap laptop, heavy laptop, big laptop, expensive lap...
# 11  [great product, great price, good price, reasonable price, low price, excellent price, fair price, decent price, cheap price, nice price, fantastic price, small price, competitive price, high pric...
# 12                                    [light weight, light laptop, light duty, standard weight, total weight, light wand, light weight perfect, light weight wooden, light entertainment, light multimedia]
# 13  [long battery life, good battery life, great battery life, short battery life, excellent battery life, decent battery life, poor battery life, amazing battery life, great battery replacement, terr...
# 14                                              [minimal space, minimal storage, minimal damage, minimal noise, minimal lint, colorful glare, high glare, minimal plastic, minimal impact, minimal battery]
# 15  [video quality, image quality, screen quality, quality construction, product quality, voice quality, construction quality, bag quality, quality ratio, camera quality, apple quality, quality hardwa...
# 16  [sound quality, sound quality, sound card, sound card, sound system, sound system, laptop area, sound bar, sound bar, laptop area, good budget laptop, good budget laptop, sound reproduction, sound...

# %% [markdown]
# # SCratch

# %%
for qphrase in monitor:
    qvec = nlp(qphrase).vector
    _, __n = nn.kneighbors([qvec], n_neighbors=10)
    print(__n)
    print(qphrase)
    print( [attributes[i] for i in __n[0]])
# Out:
# [[12020  7589 18877 21085 17309 23563 19171 19177 21558 28605]]
# Easy to set up
# ['awesome built-in surround sound', 'go-to monitor', 'excellent widescreen hp monitor', 'menu buttons faulty', 'nice freestanding stand', 'lg support unable', 'excellent built-in webcam', 'cost effective', 'expensive af', 'ok works good']
# [[ 3756 21111 10550  9048 21219 30179 20828 18312 12656 13617]]
# Quality display
# ['great picture display', 'gtx980 strix', 'quality display', 'great quality display', 'computer display', 'resolution display', 'nice quality display', 'great screen resolution', 'wide screen display', 'color display']
# [[24138 14376 28118 27779 11638  3104 21910 10059 22017  3669]]
# Good color quality
# ['great color definition', 'poor color quality', 'poor color accuracy', 'great video quality', 'nice video quality', 'excellent color quality', 'nice color definition', 'great color production', 'poor color rendition', 'good video quality']
# [[11460 13956 11194  3093 16329 18830 11510 13618 19582 16523]]
# Quality build
# ['quality build', 'good quality build', 'new system build', 'pc build', 'mst setting', 'gaming build', 'nice build', 'new desktop build', 'grandma pc build', 'dust cover']
# [[ 6093 28686 13207 27779  1016  5956 29118 14382 26221 11895]]
# Sound quality
# ['great sound quality', 'sharpness quality', 'terrible quality', 'great video quality', 'great picture quality', 'good sound quality', 'great sound bar', 'bad sound quality', 'awesome video quality', 'great screen quality']
# [[17505  7589 14777 26995 20701  2968 14356 19177 25232  5036]]
# Easy to use
# ['na overwatch', 'go-to monitor', 'hdmi use', 'review simple', 'display formats available', 'desk ready', 'budget friendly', 'cost effective', 'fix available', 'onboard flash']
# [[ 6888 21712 27166  7745 28053 18931 11772 23786  3114 29077]]
# Minimal glare
# ['minimal glare', 'noticeable impact', 'positive experience', 'minimal work', 'specific space', 'noticeable strain', 'great glossy monitor', 'actual assembly', 'professional work', 'magnificent view']
# [[ 7689 28035 10246 20302  1349 28730 10076   978 25743  3611]]
# Lightweight
# ['s220hql', 'deployment', 'g206hql', 'monitory', 'dad', 'usb male', 'motherboard', 'lo traje', 'tripod mound', 'refurb']
# [[15604 12129  7642 10774  9759 10640 20591  3088 25179 14628]]
# Good viewing angles
# ['good viewing angles', 'great viewing angles', 'nice viewing angles', 'terrible viewing angles', 'poor viewing angles', 'abysmal viewing angles', 'superior viewing angles', 'different viewing angles', 'extreme viewing angles', 'decent viewing angles']
# [[ 1517  1069 28313 23080  7542  5597 21734  9577  2104 24318]]
# Fast
# ['dual', 'fast', 'genuine', 'fast inexpensive', 'little slow', 'real', 'macbook pro late', 'separate hdmi', 'long', 'little pricey']

# %%
qvec = nlp('durability').vector
_, __n = nn.kneighbors([qvec], n_neighbors=10)
print(__n)
print(qphrase)
print( [attributes[i] for i in __n[0]])
# Out:
# [[ 1799  5790   132  1164 26156 27804  1122 30006 23119  2687]]
# Fast
# ['durability', 'violation', 'flexibility', 'portability', 'malfunction', 'continuity', 'device', 'cage', 'coloration', 'configuration']
