# %% [markdown]
# ## In this notebook
#
# * we build the skeleton code required for the flask API calls
#
# NOTE:
# - ensure that we rank reviews using length and recency, along with the given attribute scores

# %% [markdown]
# references (if required)
# - https://stackoverflow.com/questions/4928054/postgresql-wildcard-like-for-any-of-a-list-of-words
#
# - https://www.postgresql.org/docs/current/functions-array.html
#     - https://www.postgresql.org/docs/current/arrays.html
#     - array_length ( anyarray, integer ) → integer

# %%
from sqlalchemy import create_engine
import psycopg2 
import io

import pandas as pd
import json
import numpy as np

# %%
pd.options.display.max_columns = 50
pd.options.display.max_colwidth = 200
pd.options.display.max_rows = 1000

# %%
conn_string = 'postgresql+psycopg2://gabbydbuser:gabbyDBpass@localhost:5432/gabbyDB'
db = create_engine(conn_string)
conn = db.connect()

# %% [markdown]
# ## Getting attributes/phrases

# %%
negative_attributes_query = \
    '''SELECT  P.key_phrase_id, P.phrase, S.n_positive, S.n_negative, S.reviewer_idf, S.n_reviews, S.n_reviewers
    FROM key_phrase_root P, 
    (SELECT * 
    FROM key_phrase_scores 
    WHERE  n_positive - n_negative < 0 
    ORDER BY n_negative DESC LIMIT 50) S
    WHERE P.key_phrase_id=S.key_phrase_id 
    ORDER BY n_reviewers DESC
    '''
negative_phrases = pd.read_sql(negative_attributes_query, conn)

# %%
negative_phrases
# Out:
#     key_phrase_id               phrase  n_positive  n_negative  reviewer_idf  \
# 0            4327            the issue         148         167      5.119226
# 1            7184               no way         128         164      5.145298
# 2            3258           this issue         128         130      5.313382
# 3            2323         this problem         103         111      5.467533
# 4            8322             warranty          58         125      5.688075
# 5            1697           your money          41         133      5.701147
# 6            5208      the replacement          72          91      5.790554
# 7           18154         a dead pixel          67          71      5.921007
# 8            3569             a refund          25         109      5.937536
# 9            2841                 junk          32          98      5.971438
# 10          10645         the warranty          47          86      6.042897
# 11             90     customer service          55          63      6.090299
# 12           8067              arrival          55          57      6.090299
# 13           4953           the issues          54          56      6.109907
# 14           4324            the phone          45          70      6.140060
# 15           4752                china          85         121      6.225218
# 16            209             my money          28          64      6.259120
# 17           8745                 crap          32          62      6.259120
# 18           2594              3 stars          26          73      6.259120
# 19            450          replacement          43          49      6.270681
# 20           5524              garbage          28          71      6.318309
# 21           9677         the problems          39          47      6.381223
# 22          11309              my time          38          39      6.420963
# 23          10328            no signal          45          51      6.420963
# 24           3559             3 months          57          81      6.462348
# 25          12691              an hour          57          61      6.462348
# 26           3159        another brand          26          42      6.550641
# 27          32248         these issues          28          37      6.614154
# 28           9802  a different monitor          21          42      6.630683
# 29           7884                  doa          36          48      6.630683
# 30          11950       the dvd player          35          39      6.630683
# 31           4101            your time          25          43      6.647491
# 32           4725              2 stars           8          53      6.647491
# 33            763         tech support          32          46      6.681977
# 34           7042      quality control          21          41      6.717695
# 35          12190             no avail          11          40      6.833208
# 36           2673              a waste          25          31      6.853827
# 37           7338              2 weeks          39          51      6.853827
# 38            735               return          14          34      6.918365
# 39           5506            two stars           5          43      6.918365
# 40           7152            a company          16          33      6.940838
# 41          11869              no help          14          32      6.987358
# 42           3201                 pyle          17          38      7.036148
# 43           1005             one year          33          44      7.036148
# 44           3683             4 months          20          47      7.169680
# 45          27875                  meh          17          34      7.259292
# 46           9885              3 weeks          19          37      7.291041
# 47          28323              2 hours          26          31      7.291041
# 48           8968              30 days          16          43      7.357732
# 49          66478        three stars.i           0          34      7.834656
#
#     n_reviews  n_reviewers
# 0         276          272
# 1         272          265
# 2         232          224
# 3         199          192
# 4         162          154
# 5         162          152
# 6         144          139
# 7         126          122
# 8         122          120
# 9         120          116
# 10        115          108
# 11        107          103
# 12        104          103
# 13        102          101
# 14        101           98
# 15         90           90
# 16         89           87
# 17         87           87
# 18         90           87
# 19         87           86
# 20         83           82
# 21         80           77
# 22         75           74
# 23         75           74
# 24         72           71
# 25         72           71
# 26         67           65
# 27         61           61
# 28         61           60
# 29         60           60
# 30         63           60
# 31         61           59
# 32         59           59
# 33         63           57
# 34         56           55
# 35         51           49
# 36         51           48
# 37         49           48
# 38         47           45
# 39         46           45
# 40         46           44
# 41         44           42
# 42         44           40
# 43         45           40
# 44         35           35
# 45         32           32
# 46         31           31
# 47         31           31
# 48         30           29
# 49         18           18

# %%
positive_attributes_query = \
     '''SELECT  P.key_phrase_id, P.phrase, S.n_positive, S.n_negative, S.reviewer_idf, S.n_reviews, S.n_reviewers
    FROM key_phrase_root P, 
    (SELECT * 
    FROM key_phrase_scores 
    WHERE  n_positive - n_negative > 0 
    ORDER BY n_positive DESC LIMIT 50) S
    WHERE P.key_phrase_id=S.key_phrase_id 
    ORDER BY n_positive DESC
    '''
positive_phrases = pd.read_sql(positive_attributes_query, conn)

# %%
positive_phrases
# Out:
#     key_phrase_id          phrase  n_positive  n_negative  reviewer_idf  \
# 0               3    this monitor       10892        2788      1.776702
# 1              29     the monitor        9363        3182      1.961287
# 2              26       the price        4541         644      2.321900
# 3               9      the screen        4272        1855      2.420286
# 4             181               2        2554         839      2.893808
# 5             108         samsung        2048         911      3.519393
# 6            2066       the stand        2033         476      3.221187
# 7           18621              4k        1892         439      3.716523
# 8             104          second        1857         557      3.145349
# 9            2007         the box        1695         453      3.239536
# 10            597           a lot        1631         453      3.276694
# 11            184               3        1577         620      3.309853
# 12           2383      the colors        1525         369      3.371946
# 13             41          amazon        1523         776      3.281364
# 14             57       a monitor        1441         470      3.336700
# 15             48     the picture        1383         399      3.427260
# 16           2351            hdmi        1331         316      3.596532
# 17           2132     the display        1263         462      3.636619
# 18           6286         windows        1223         401      3.671442
# 19           2444   great monitor        1199          78      3.681868
# 20            981               1        1183         472      3.625826
# 21            109          gaming        1158         176      3.694170
# 22           9095              27        1148         258      3.811291
# 23           1340               4        1139         350      3.626652
# 24            253               5        1129         313      3.650911
# 25            880        speakers        1127         222      3.694170
# 26           7252              24        1078         200      3.841565
# 27           2414          colors        1057         290      3.663694
# 28           2122           games        1033         161      3.866463
# 29           3660            work        1019         199      3.751485
# 30             21    the speakers         991         191      3.867514
# 31            294       the money         968         164      3.804356
# 32            499               =         951         258      5.308928
# 33          10181           1080p         947         183      3.947381
# 34          17270           144hz         935         198      4.549161
# 35            819         monitor         930         343      3.718333
# 36            250          movies         904         166      3.911583
# 37             39            time         903         331      3.780941
# 38             37     the quality         876         197      3.866463
# 39            372        the base         873         212      4.031704
# 40           1743         my desk         869         130      3.963455
# 41           1029    this product         861         374      3.795511
# 42           4864        monitors         853         256      3.850829
# 43           4866  these monitors         809         248      4.009645
# 44             76      brightness         770         186      4.018166
# 45            494         quality         767         174      3.988061
# 46            454      this thing         766         241      3.996399
# 47            200  the brightness         749         178      4.054262
# 48           4223  the resolution         748         178      4.012072
# 49           4307             dvi         744         138      4.144389
#
#     n_reviews  n_reviewers
# 0        8259         7695
# 1        6819         6398
# 2        4611         4461
# 3        4265         4043
# 4        2618         2518
# 5        1441         1347
# 6        1896         1815
# 7        1154         1106
# 8        2023         1958
# 9        1866         1782
# 10       1804         1717
# 11       1737         1661
# 12       1646         1561
# 13       1775         1709
# 14       1701         1617
# 15       1544         1477
# 16       1307         1247
# 17       1265         1198
# 18       1203         1157
# 19       1175         1145
# 20       1270         1211
# 21       1171         1131
# 22       1045         1006
# 23       1252         1210
# 24       1234         1181
# 25       1163         1131
# 26       1024          976
# 27       1214         1166
# 28       1001          952
# 29       1100         1068
# 30        993          951
# 31       1036         1013
# 32        243          225
# 33        911          878
# 34        521          481
# 35       1141         1104
# 36        946          910
# 37       1076         1037
# 38        976          952
# 39        831          807
# 40        892          864
# 41       1060         1022
# 42       1003          967
# 43        843          825
# 44        853          818
# 45        868          843
# 46        859          836
# 47        827          789
# 48        850          823
# 49        756          721

# %%
attributes = pd.concat([positive_phrases, negative_phrases]).reset_index(drop=True)

# %%
def filter_phrases_containing_brand_model_terms(df, brand_model_terms):
    pattern = '(' + '|'.join(brand_model_terms) + ')'
    return df[ ~df['phrase'].str.match(pattern, case=False)]

def is_alpha_numeric(df):
    """
    checking if every token in the phrase is not a string of punctuations
    """
    alnums =  df['phrase'].apply(lambda p: all([t.isalnum() for t in p.split()]))
    return df[alnums]

def drop_numeric_phrases(df):
    """
    remove phrases that are just numbers
    """
    return df[~df['phrase'].apply(lambda p: len(p.split()) == 1 and p.isnumeric())]

# %%
drop_numeric_phrases(is_alpha_numeric(attributes))
# Out:
#     key_phrase_id               phrase  n_positive  n_negative  reviewer_idf  \
# 0               3         this monitor       10892        2788      1.776702
# 1              29          the monitor        9363        3182      1.961287
# 2              26            the price        4541         644      2.321900
# 3               9           the screen        4272        1855      2.420286
# 5             108              samsung        2048         911      3.519393
# 6            2066            the stand        2033         476      3.221187
# 7           18621                   4k        1892         439      3.716523
# 8             104               second        1857         557      3.145349
# 9            2007              the box        1695         453      3.239536
# 10            597                a lot        1631         453      3.276694
# 12           2383           the colors        1525         369      3.371946
# 13             41               amazon        1523         776      3.281364
# 14             57            a monitor        1441         470      3.336700
# 15             48          the picture        1383         399      3.427260
# 16           2351                 hdmi        1331         316      3.596532
# 17           2132          the display        1263         462      3.636619
# 18           6286              windows        1223         401      3.671442
# 19           2444        great monitor        1199          78      3.681868
# 21            109               gaming        1158         176      3.694170
# 25            880             speakers        1127         222      3.694170
# 27           2414               colors        1057         290      3.663694
# 28           2122                games        1033         161      3.866463
# 29           3660                 work        1019         199      3.751485
# 30             21         the speakers         991         191      3.867514
# 31            294            the money         968         164      3.804356
# 33          10181                1080p         947         183      3.947381
# 34          17270                144hz         935         198      4.549161
# 35            819              monitor         930         343      3.718333
# 36            250               movies         904         166      3.911583
# 37             39                 time         903         331      3.780941
# 38             37          the quality         876         197      3.866463
# 39            372             the base         873         212      4.031704
# 40           1743              my desk         869         130      3.963455
# 41           1029         this product         861         374      3.795511
# 42           4864             monitors         853         256      3.850829
# 43           4866       these monitors         809         248      4.009645
# 44             76           brightness         770         186      4.018166
# 45            494              quality         767         174      3.988061
# 46            454           this thing         766         241      3.996399
# 47            200       the brightness         749         178      4.054262
# 48           4223       the resolution         748         178      4.012072
# 49           4307                  dvi         744         138      4.144389
# 50           4327            the issue         148         167      5.119226
# 51           7184               no way         128         164      5.145298
# 52           3258           this issue         128         130      5.313382
# 53           2323         this problem         103         111      5.467533
# 54           8322             warranty          58         125      5.688075
# 55           1697           your money          41         133      5.701147
# 56           5208      the replacement          72          91      5.790554
# 57          18154         a dead pixel          67          71      5.921007
# 58           3569             a refund          25         109      5.937536
# 59           2841                 junk          32          98      5.971438
# 60          10645         the warranty          47          86      6.042897
# 61             90     customer service          55          63      6.090299
# 62           8067              arrival          55          57      6.090299
# 63           4953           the issues          54          56      6.109907
# 64           4324            the phone          45          70      6.140060
# 65           4752                china          85         121      6.225218
# 66            209             my money          28          64      6.259120
# 67           8745                 crap          32          62      6.259120
# 68           2594              3 stars          26          73      6.259120
# 69            450          replacement          43          49      6.270681
# 70           5524              garbage          28          71      6.318309
# 71           9677         the problems          39          47      6.381223
# 72          11309              my time          38          39      6.420963
# 73          10328            no signal          45          51      6.420963
# 74           3559             3 months          57          81      6.462348
# 75          12691              an hour          57          61      6.462348
# 76           3159        another brand          26          42      6.550641
# 77          32248         these issues          28          37      6.614154
# 78           9802  a different monitor          21          42      6.630683
# 79           7884                  doa          36          48      6.630683
# 80          11950       the dvd player          35          39      6.630683
# 81           4101            your time          25          43      6.647491
# 82           4725              2 stars           8          53      6.647491
# 83            763         tech support          32          46      6.681977
# 84           7042      quality control          21          41      6.717695
# 85          12190             no avail          11          40      6.833208
# 86           2673              a waste          25          31      6.853827
# 87           7338              2 weeks          39          51      6.853827
# 88            735               return          14          34      6.918365
# 89           5506            two stars           5          43      6.918365
# 90           7152            a company          16          33      6.940838
# 91          11869              no help          14          32      6.987358
# 92           3201                 pyle          17          38      7.036148
# 93           1005             one year          33          44      7.036148
# 94           3683             4 months          20          47      7.169680
# 95          27875                  meh          17          34      7.259292
# 96           9885              3 weeks          19          37      7.291041
# 97          28323              2 hours          26          31      7.291041
# 98           8968              30 days          16          43      7.357732
#
#     n_reviews  n_reviewers
# 0        8259         7695
# 1        6819         6398
# 2        4611         4461
# 3        4265         4043
# 5        1441         1347
# 6        1896         1815
# 7        1154         1106
# 8        2023         1958
# 9        1866         1782
# 10       1804         1717
# 12       1646         1561
# 13       1775         1709
# 14       1701         1617
# 15       1544         1477
# 16       1307         1247
# 17       1265         1198
# 18       1203         1157
# 19       1175         1145
# 21       1171         1131
# 25       1163         1131
# 27       1214         1166
# 28       1001          952
# 29       1100         1068
# 30        993          951
# 31       1036         1013
# 33        911          878
# 34        521          481
# 35       1141         1104
# 36        946          910
# 37       1076         1037
# 38        976          952
# 39        831          807
# 40        892          864
# 41       1060         1022
# 42       1003          967
# 43        843          825
# 44        853          818
# 45        868          843
# 46        859          836
# 47        827          789
# 48        850          823
# 49        756          721
# 50        276          272
# 51        272          265
# 52        232          224
# 53        199          192
# 54        162          154
# 55        162          152
# 56        144          139
# 57        126          122
# 58        122          120
# 59        120          116
# 60        115          108
# 61        107          103
# 62        104          103
# 63        102          101
# 64        101           98
# 65         90           90
# 66         89           87
# 67         87           87
# 68         90           87
# 69         87           86
# 70         83           82
# 71         80           77
# 72         75           74
# 73         75           74
# 74         72           71
# 75         72           71
# 76         67           65
# 77         61           61
# 78         61           60
# 79         60           60
# 80         63           60
# 81         61           59
# 82         59           59
# 83         63           57
# 84         56           55
# 85         51           49
# 86         51           48
# 87         49           48
# 88         47           45
# 89         46           45
# 90         46           44
# 91         44           42
# 92         44           40
# 93         45           40
# 94         35           35
# 95         32           32
# 96         31           31
# 97         31           31
# 98         30           29

# %%
monitor_brands_query = \
    '''SELECT DISTINCT(brand)
        FROM baseline_products 
        WHERE title ILIKE '%%inch%%' 
        AND title ILIKE '%%monitor%%' 
    '''
monitor_brands = pd.read_sql(monitor_brands_query, conn)

# %%
monitor_brands.head()
# Out:
#                   brand
# 0
# 1  101 Audio Video Inc.
# 2                1byone
# 3                AFUNTA
# 4                AMOCAM

# %%
attributes_filtered = \
        filter_phrases_containing_brand_model_terms(
                drop_numeric_phrases(
                        is_alpha_numeric(attributes)
                ), 
                monitor_brands[monitor_brands['brand'].str.len() > 1]['brand'].tolist()
        )

# %%
attributes.shape
# Out:
# (100, 7)

# %%
attributes_filtered.shape
# Out:
# (89, 7)

# %%
attributes_filtered
# Out:
#     key_phrase_id               phrase  n_positive  n_negative  reviewer_idf  \
# 0               3         this monitor       10892        2788      1.776702
# 1              29          the monitor        9363        3182      1.961287
# 2              26            the price        4541         644      2.321900
# 3               9           the screen        4272        1855      2.420286
# 6            2066            the stand        2033         476      3.221187
# 7           18621                   4k        1892         439      3.716523
# 8             104               second        1857         557      3.145349
# 9            2007              the box        1695         453      3.239536
# 10            597                a lot        1631         453      3.276694
# 12           2383           the colors        1525         369      3.371946
# 13             41               amazon        1523         776      3.281364
# 14             57            a monitor        1441         470      3.336700
# 15             48          the picture        1383         399      3.427260
# 16           2351                 hdmi        1331         316      3.596532
# 17           2132          the display        1263         462      3.636619
# 18           6286              windows        1223         401      3.671442
# 19           2444        great monitor        1199          78      3.681868
# 21            109               gaming        1158         176      3.694170
# 25            880             speakers        1127         222      3.694170
# 27           2414               colors        1057         290      3.663694
# 28           2122                games        1033         161      3.866463
# 29           3660                 work        1019         199      3.751485
# 30             21         the speakers         991         191      3.867514
# 31            294            the money         968         164      3.804356
# 33          10181                1080p         947         183      3.947381
# 34          17270                144hz         935         198      4.549161
# 35            819              monitor         930         343      3.718333
# 36            250               movies         904         166      3.911583
# 37             39                 time         903         331      3.780941
# 38             37          the quality         876         197      3.866463
# 39            372             the base         873         212      4.031704
# 40           1743              my desk         869         130      3.963455
# 41           1029         this product         861         374      3.795511
# 42           4864             monitors         853         256      3.850829
# 43           4866       these monitors         809         248      4.009645
# 44             76           brightness         770         186      4.018166
# 45            494              quality         767         174      3.988061
# 46            454           this thing         766         241      3.996399
# 47            200       the brightness         749         178      4.054262
# 48           4223       the resolution         748         178      4.012072
# 49           4307                  dvi         744         138      4.144389
# 50           4327            the issue         148         167      5.119226
# 51           7184               no way         128         164      5.145298
# 52           3258           this issue         128         130      5.313382
# 53           2323         this problem         103         111      5.467533
# 54           8322             warranty          58         125      5.688075
# 55           1697           your money          41         133      5.701147
# 56           5208      the replacement          72          91      5.790554
# 57          18154         a dead pixel          67          71      5.921007
# 58           3569             a refund          25         109      5.937536
# 59           2841                 junk          32          98      5.971438
# 60          10645         the warranty          47          86      6.042897
# 61             90     customer service          55          63      6.090299
# 62           8067              arrival          55          57      6.090299
# 63           4953           the issues          54          56      6.109907
# 64           4324            the phone          45          70      6.140060
# 65           4752                china          85         121      6.225218
# 66            209             my money          28          64      6.259120
# 67           8745                 crap          32          62      6.259120
# 68           2594              3 stars          26          73      6.259120
# 69            450          replacement          43          49      6.270681
# 70           5524              garbage          28          71      6.318309
# 71           9677         the problems          39          47      6.381223
# 72          11309              my time          38          39      6.420963
# 73          10328            no signal          45          51      6.420963
# 74           3559             3 months          57          81      6.462348
# 75          12691              an hour          57          61      6.462348
# 76           3159        another brand          26          42      6.550641
# 77          32248         these issues          28          37      6.614154
# 78           9802  a different monitor          21          42      6.630683
# 79           7884                  doa          36          48      6.630683
# 80          11950       the dvd player          35          39      6.630683
# 81           4101            your time          25          43      6.647491
# 82           4725              2 stars           8          53      6.647491
# 83            763         tech support          32          46      6.681977
# 84           7042      quality control          21          41      6.717695
# 85          12190             no avail          11          40      6.833208
# 86           2673              a waste          25          31      6.853827
# 87           7338              2 weeks          39          51      6.853827
# 88            735               return          14          34      6.918365
# 89           5506            two stars           5          43      6.918365
# 90           7152            a company          16          33      6.940838
# 91          11869              no help          14          32      6.987358
# 93           1005             one year          33          44      7.036148
# 94           3683             4 months          20          47      7.169680
# 95          27875                  meh          17          34      7.259292
# 96           9885              3 weeks          19          37      7.291041
# 97          28323              2 hours          26          31      7.291041
# 98           8968              30 days          16          43      7.357732
#
#     n_reviews  n_reviewers
# 0        8259         7695
# 1        6819         6398
# 2        4611         4461
# 3        4265         4043
# 6        1896         1815
# 7        1154         1106
# 8        2023         1958
# 9        1866         1782
# 10       1804         1717
# 12       1646         1561
# 13       1775         1709
# 14       1701         1617
# 15       1544         1477
# 16       1307         1247
# 17       1265         1198
# 18       1203         1157
# 19       1175         1145
# 21       1171         1131
# 25       1163         1131
# 27       1214         1166
# 28       1001          952
# 29       1100         1068
# 30        993          951
# 31       1036         1013
# 33        911          878
# 34        521          481
# 35       1141         1104
# 36        946          910
# 37       1076         1037
# 38        976          952
# 39        831          807
# 40        892          864
# 41       1060         1022
# 42       1003          967
# 43        843          825
# 44        853          818
# 45        868          843
# 46        859          836
# 47        827          789
# 48        850          823
# 49        756          721
# 50        276          272
# 51        272          265
# 52        232          224
# 53        199          192
# 54        162          154
# 55        162          152
# 56        144          139
# 57        126          122
# 58        122          120
# 59        120          116
# 60        115          108
# 61        107          103
# 62        104          103
# 63        102          101
# 64        101           98
# 65         90           90
# 66         89           87
# 67         87           87
# 68         90           87
# 69         87           86
# 70         83           82
# 71         80           77
# 72         75           74
# 73         75           74
# 74         72           71
# 75         72           71
# 76         67           65
# 77         61           61
# 78         61           60
# 79         60           60
# 80         63           60
# 81         61           59
# 82         59           59
# 83         63           57
# 84         56           55
# 85         51           49
# 86         51           48
# 87         49           48
# 88         47           45
# 89         46           45
# 90         46           44
# 91         44           42
# 93         45           40
# 94         35           35
# 95         32           32
# 96         31           31
# 97         31           31
# 98         30           29

# %%
attributes_filtered[['key_phrase_id', 'phrase']].to_json(orient='records')
# Out:
# '[{"key_phrase_id":3,"phrase":"this monitor"},{"key_phrase_id":29,"phrase":"the monitor"},{"key_phrase_id":26,"phrase":"the price"},{"key_phrase_id":9,"phrase":"the screen"},{"key_phrase_id":2066,"phrase":"the stand"},{"key_phrase_id":18621,"phrase":"4k"},{"key_phrase_id":104,"phrase":"second"},{"key_phrase_id":2007,"phrase":"the box"},{"key_phrase_id":597,"phrase":"a lot"},{"key_phrase_id":2383,"phrase":"the colors"},{"key_phrase_id":41,"phrase":"amazon"},{"key_phrase_id":57,"phrase":"a monitor"},{"key_phrase_id":48,"phrase":"the picture"},{"key_phrase_id":2351,"phrase":"hdmi"},{"key_phrase_id":2132,"phrase":"the display"},{"key_phrase_id":6286,"phrase":"windows"},{"key_phrase_id":2444,"phrase":"great monitor"},{"key_phrase_id":109,"phrase":"gaming"},{"key_phrase_id":880,"phrase":"speakers"},{"key_phrase_id":2414,"phrase":"colors"},{"key_phrase_id":2122,"phrase":"games"},{"key_phrase_id":3660,"phrase":"work"},{"key_phrase_id":21,"phrase":"the speakers"},{"key_phrase_id":294,"phrase":"the money"},{"key_phrase_id":10181,"phrase":"1080p"},{"key_phrase_id":17270,"phrase":"144hz"},{"key_phrase_id":819,"phrase":"monitor"},{"key_phrase_id":250,"phrase":"movies"},{"key_phrase_id":39,"phrase":"time"},{"key_phrase_id":37,"phrase":"the quality"},{"key_phrase_id":372,"phrase":"the base"},{"key_phrase_id":1743,"phrase":"my desk"},{"key_phrase_id":1029,"phrase":"this product"},{"key_phrase_id":4864,"phrase":"monitors"},{"key_phrase_id":4866,"phrase":"these monitors"},{"key_phrase_id":76,"phrase":"brightness"},{"key_phrase_id":494,"phrase":"quality"},{"key_phrase_id":454,"phrase":"this thing"},{"key_phrase_id":200,"phrase":"the brightness"},{"key_phrase_id":4223,"phrase":"the resolution"},{"key_phrase_id":4307,"phrase":"dvi"},{"key_phrase_id":4327,"phrase":"the issue"},{"key_phrase_id":7184,"phrase":"no way"},{"key_phrase_id":3258,"phrase":"this issue"},{"key_phrase_id":2323,"phrase":"this problem"},{"key_phrase_id":8322,"phrase":"warranty"},{"key_phrase_id":1697,"phrase":"your money"},{"key_phrase_id":5208,"phrase":"the replacement"},{"key_phrase_id":18154,"phrase":"a dead pixel"},{"key_phrase_id":3569,"phrase":"a refund"},{"key_phrase_id":2841,"phrase":"junk"},{"key_phrase_id":10645,"phrase":"the warranty"},{"key_phrase_id":90,"phrase":"customer service"},{"key_phrase_id":8067,"phrase":"arrival"},{"key_phrase_id":4953,"phrase":"the issues"},{"key_phrase_id":4324,"phrase":"the phone"},{"key_phrase_id":4752,"phrase":"china"},{"key_phrase_id":209,"phrase":"my money"},{"key_phrase_id":8745,"phrase":"crap"},{"key_phrase_id":2594,"phrase":"3 stars"},{"key_phrase_id":450,"phrase":"replacement"},{"key_phrase_id":5524,"phrase":"garbage"},{"key_phrase_id":9677,"phrase":"the problems"},{"key_phrase_id":11309,"phrase":"my time"},{"key_phrase_id":10328,"phrase":"no signal"},{"key_phrase_id":3559,"phrase":"3 months"},{"key_phrase_id":12691,"phrase":"an hour"},{"key_phrase_id":3159,"phrase":"another brand"},{"key_phrase_id":32248,"phrase":"these issues"},{"key_phrase_id":9802,"phrase":"a different monitor"},{"key_phrase_id":7884,"phrase":"doa"},{"key_phrase_id":11950,"phrase":"the dvd player"},{"key_phrase_id":4101,"phrase":"your time"},{"key_phrase_id":4725,"phrase":"2 stars"},{"key_phrase_id":763,"phrase":"tech support"},{"key_phrase_id":7042,"phrase":"quality control"},{"key_phrase_id":12190,"phrase":"no avail"},{"key_phrase_id":2673,"phrase":"a waste"},{"key_phrase_id":7338,"phrase":"2 weeks"},{"key_phrase_id":735,"phrase":"return"},{"key_phrase_id":5506,"phrase":"two stars"},{"key_phrase_id":7152,"phrase":"a company"},{"key_phrase_id":11869,"phrase":"no help"},{"key_phrase_id":1005,"phrase":"one year"},{"key_phrase_id":3683,"phrase":"4 months"},{"key_phrase_id":27875,"phrase":"meh"},{"key_phrase_id":9885,"phrase":"3 weeks"},{"key_phrase_id":28323,"phrase":"2 hours"},{"key_phrase_id":8968,"phrase":"30 days"}]'

# %% [markdown]
# # Getting reviews given attributes

# %%
attributes_filtered.sample(5)
# Out:
#     key_phrase_id   phrase  n_positive  n_negative  reviewer_idf  n_reviews  \
# 87           7338  2 weeks          39          51      6.853827         49
# 79           7884      doa          36          48      6.630683         60
# 36            250   movies         904         166      3.911583        946
# 95          27875      meh          17          34      7.259292         32
# 45            494  quality         767         174      3.988061        868
#
#     n_reviewers
# 87           48
# 79           60
# 36          910
# 95           32
# 45          843

# %%
select * from table where value ~* 'the price|the stand|2 weeks|quality'

# %%
phrase_ids_query = \
    '''SELECT key_phrase_id, phrase 
        FROM key_phrase_root 
        WHERE phrase IN ('the price', 'the stand', '2 weeks', 'quality')
    '''
query_phrases = pd.read_sql(phrase_ids_query, conn)

# %%
query_phrases
# Out:
#    key_phrase_id     phrase
# 0             26  the price
# 1            494    quality
# 2           2066  the stand
# 3           7338    2 weeks

# %%
review_results_query = \
    '''SELECT key_phrase_id, review_id 
        FROM key_phrase_reviews 
        WHERE key_phrase_id IN 
        (SELECT key_phrase_id 
        FROM key_phrase_root 
        WHERE phrase IN ('the price', 'the stand', '2 weeks', 'quality'))
    '''
review_ids_for_query = pd.read_sql(review_results_query, conn)

# %%
review_ids_for_query
# Out:
#       key_phrase_id  review_id
# 0                26     139343
# 1                26     360959
# 2                26     721407
# 3                26     721408
# 4                26     360976
# ...             ...        ...
# 7419           7338     970614
# 7420           7338     628984
# 7421           7338     178426
# 7422           7338    1379579
# 7423           7338    1038588
#
# [7424 rows x 2 columns]

# %%
review_ids_for_query = review_ids_for_query.merge(query_phrases, on='key_phrase_id', how='left')

# %%
review_ids_for_query = review_ids_for_query.groupby('review_id')['phrase'].apply(list).reset_index()
review_ids_for_query['n_matches'] = review_ids_for_query['phrase'].apply(len)

# %%
top_matched_reviews = review_ids_for_query.sort_values('n_matches', ascending=False).head(25)
top_matched_reviews
# Out:
#       review_id                           phrase  n_matches
# 2317     473934  [the price, quality, the stand]          3
# 4682     878360  [the price, quality, the stand]          3
# 1104     246770  [the price, quality, the stand]          3
# 5632    1118343  [the price, quality, the stand]          3
# 1561     346497  [the price, quality, the stand]          3
# 5244     983402  [the price, quality, the stand]          3
# 949      227216  [the price, quality, the stand]          3
# 4508     847415  [the price, quality, the stand]          3
# 637      173319  [the price, quality, the stand]          3
# 2851     572342  [the price, quality, the stand]          3
# 3767     713825  [the price, quality, the stand]          3
# 6272    1248438  [the price, quality, the stand]          3
# 4345     776932  [the price, quality, the stand]          3
# 3136     594937  [the price, quality, the stand]          3
# 834      209586  [the price, quality, the stand]          3
# 3957     736067  [the price, quality, the stand]          3
# 887      222049  [the price, quality, the stand]          3
# 1594     352163           [the price, the stand]          2
# 2830     567449             [the price, quality]          2
# 5417    1033521           [the price, the stand]          2
# 6069    1204325           [the price, the stand]          2
# 5681    1128633             [the price, quality]          2
# 453      112406             [the price, quality]          2
# 2836     568189           [the price, the stand]          2
# 2225     473333           [the price, the stand]          2

# %%
fetch_matched_reviews_query = \
    f'''SELECT *
        FROM baseline_reviews
        WHERE review_id IN (
            {','.join(top_matched_reviews['review_id'].astype(str).tolist())}
        )
        
    '''
matched_reviews = pd.read_sql(fetch_matched_reviews_query, conn)

# %%
matched_reviews
# Out:
#     review_id  rating sentiment  vote  verified      reviewerID        asin  \
# 0      173319     3.0  negative   5.0      True  A1WT047CVF256C  B001LYPNFQ
# 1      112406     5.0  positive   0.0      True  A28GZ52326W7ET  B00139S3U6
# 2      352163     5.0  positive   0.0      True  A1LDB0HGS322GA  B005HPSFWI
# 3      227216     5.0  positive   0.0      True  A3NM39O6R8H3A5  B0039648BO
# 4      209586     5.0  positive  12.0     False  A25A7C826KIX2R  B002MT6SDU
# 5      222049     5.0  positive   0.0      True  A3376ZXV304DQV  B002ZVCGXQ
# 6      246770     5.0  positive   0.0      True  A37863TC1Q7059  B003Y3BJ7S
# 7      346497     4.0  positive  94.0     False  A2AY4YUOX2N1BQ  B005FNH9RE
# 8      473333     4.0  positive   0.0      True  A2GS7CV57Y7UT2  B0098Y77U0
# 9      473934     5.0  positive   0.0      True  A11Z60P0Z6CHFO  B0098Y77U0
# 10     594937     3.0  negative   2.0     False  A1F5YYNOS77MXM  B00CLZ047Q
# 11     568189     4.0  positive   6.0      True   ANXVC9YPIJBL4  B00BWBEL1U
# 12     567449     5.0  positive   7.0      True  A3F6KTX44THL5C  B00BV9AOL4
# 13     572342     4.0  positive  26.0      True   ATVW0VQARUDIG  B00C18YQ8Q
# 14    1248438     5.0  positive   5.0      True  A14UAWC9WEXD80  B01ERKL17E
# 15     713825     5.0  positive   0.0     False   AAFSO9JA44IAF  B00GTV05XG
# 16     736067     3.0  negative  38.0      True  A3DA8PZUYZ38RN  B00HY7PAUC
# 17     878360     4.0  positive   3.0     False   ASFW4ZMNZJKDA  B00NM76PXY
# 18    1033521     3.0  negative  18.0      True  A24ZGNMHCZPPAW  B00Y09G6JG
# 19    1118343     5.0  positive   9.0     False  A206M3IUN3N5IR  B015FP25V6
# 20    1128633     4.0  positive   0.0      True  A1P0TLLTHVTZNC  B015WCV70W
# 21     776932     4.0  positive   3.0      True  A38KK0SZYEH5UD  B00JR6GCZA
# 22     847415     5.0  positive   6.0     False   A6T1RHMQ9NSE4  B00M9B3XN4
# 23     983402     5.0  positive   2.0     False  A1UQUDT2Q0YENM  B00UGI1NGG
# 24    1204325     4.0  positive   6.0      True   A1FUO6JIIQZ5S  B01BV1X9DG
#
#                                                                                                                                                                                                  reviewText  \
# 0   Overall a nice monitor. Yes, it has tint problems out of the box, but you should calibrate every monitor you get anyway, regardless of quality. It can make a huge difference, even if you're not ed...
# 1   The latest generation of Hewlett Packard widescreen computer monitors sets a new standard for quality and value, and this model is probably just about right for your average desktop user. At 22inc...
# 2   I wanted to declutter my desk so I bought this stand to hold my 2 24 inch monitors. The price of the stand was good and it looks nice on my desk. The monitors are very stable. When mounting the mo...
# 3   I'm going to start this review of with what I feel are this monitors shortcomings, because there really aren't that many of them.\nAlso keep in mind that, my opinion of a pro or con, feature wise,...
# 4   I bought this to replace an older 4:3 Princeton LCD.  Worked fine right out of the box with my Lenovo T61 laptop and its built in NVidia graphics card.  My previous experience with 15-17" widescre...
# 5   This has to be the best monitor you can buy for the price.\n\nPros:\nPrice - for under two hundred, a bargain.\nQuality - the best monitor I've ever owned. No dead pixels, scratches, or anything. ...
# 6   Finally deciding to retire a 21" CRT Viewsonic mainly because it was making my computer room very hot in the summer.  I stayed with Viewsonic because of the positive experience I had for the past ...
# 7   *REVIEW UPDATED!*\n\nI recently built myself a desktop, so of course it was time for a new monitor. I knew I wanted LED for the power savings alone (and the arguably better blacks/contrast) and LG...
# 8   <div id="video-block-R9POUR97PUQWU" class="a-section a-spacing-small a-spacing-top-mini video-block"></div><input type="hidden" name="" value="https://images-na.ssl-images-amazon.com/images/I/D1yx...
# 9   I bought this monitor in early 2015 and I'm actually back to buy another for a dual monitor setup which brings me to this review I forgot to leave earlier. This monitor is great for my general pur...
# 10  i recently purchased the Best Buy version of this monitor (i2367F, which lacks HDMI input and internal speakers). I'll only comment on issues that should be common to both.  As others have said, t...
# 11  I've bought several of these monitors over the years, both for work and for home. Taking half a star off for the somewhat flimsy stand, but the monitor mounts to a swing arm without trouble. I lik...
# 12  Giving 4 stars because I've only had it 2 days.  Will revise later.  I've been considering this monitor for over a month but hesitated due to some of the negative reviews.  Mine was in perfect con...
# 13  I own several Samsung monitors and they are all great! The only real issue that appears to apply to all of them is the stand. They either completely lack adjustment capabilities or offer limited a...
# 14  It works. No problem out of the box. Ran it off my laptop for a couple hours and everything is up to scratch. No problems no dead pixels.\n\n The only thing I don't like is the TV noise it makes w...
# 15  We've been purchasing these monitors since they came out, and I have been impressed with their reliability and quality for the price. While they've seemingly been replaced by a newer model, the di...
# 16  So I was really worried about buying these monitors based on the reviews. However, they are absolutely the cheapest option to get both 144Hz and Freesync, so I bit the bullet and ordered 2.\n\nFir...
# 17  My teenage son was very interested in trying this out, and wrote the bulk of this review. (This is for the 22-inch model.)\n\nOur assessment is that this is a good monitor for the price. "A cheap ...
# 18  The concept of an ultrawide screen sounds good in theory, but in practice it has issues, and this monitor specifically misses the target.\n\nPROS:\n- great screen real estate, you can put three do...
# 19  <div id="video-block-R2UW8188LALIO0" class="a-section a-spacing-small a-spacing-top-mini video-block"></div><input type="hidden" name="" value="https://images-na.ssl-images-amazon.com/images/I/F1O...
# 20                I'm impressed with this monitor for the price. Good color and quality, with an impressive viewing angle. Simple to set up, too. Most significant drawback is the blacks aren't very dark.
# 21  I use the LG UM95 as a monitor for my circa 2012 Mac Book Pro and for an Intel NUC device running Linux. My aging eyes need all the real estate they can get. I was a bit concerned about the wait f...
# 22  Just like every product I've ever received from Dell, this monitor comes securely packaged to avoid any kind of damage upon arrival. This is always a huge plus for me, especially when dealing with...
# 23  There's nothing wrong with this monitor, but nothing amazing either. It does seem one step above other budget 24". It's a no-frills 24" monitor, but it looks good, feels solid, and has a three yea...
# 24  This is an excellent monitor for the price. I was in the market for a large monitor. I only wanted to have one big display, and the resolution of HDTVs was not crisp enough to read the text on the...
#
#                                                                                                                 reviewTitle  \
# 0                                                                                I would give 3.5 stars if it were possible
# 1                                                                                          HP Monitor Beats The Competition
# 2                                                                                        Good value, looks nice on the desk
# 3                                                                                       Best purchase I have made this year
# 4                                                                                                         Excellent Monitor
# 5                                                                                                             Great Product
# 6                                                                              Plenty of screen for photo, video and gaming
# 7                                                                                                For the price - excellent!
# 8                                                                                            Tilt difficult, NOT impossible
# 9                                                                                  A year later and still running like new!
# 10                                                                                      Good monitor if the price is right.
# 11                                         Serviceable secondary monitor. Base comes completely off. Not great in portrait.
# 12                                                                                                             Very Nice :)
# 13                                                                                          Good monitor, not so good stand
# 14                                                                        Top quality product model from samsung yet again.
# 15                                                                                  Good Mid-Range Monitor w/ Pros and Cons
# 16                                                              Just OK. Fine for budget, but if you can spend more, do it.
# 17                                                                                              Good monitor for the price.
# 18  Do your homework to make sure this is right for you - it has lots of problems that are not really discussed in reviews.
# 19                                                                                                         Awesome Product!
# 20                                                                                                      Great for the price
# 21                                                                                                                     Nice
# 22                                                                                              "Big Screen - Little Price"
# 23                                                          A bit better than most budget 24" monitors, but nothing amazing
# 24                                                                                        Excellent monitor for the price!!
#
#    reviewTime
# 0  2010-11-02
# 1  2008-12-20
# 2  2013-10-01
# 3  2012-11-28
# 4  2009-12-29
# 5  2010-07-23
# 6  2013-01-31
# 7  2012-03-07
# 8  2016-10-05
# 9  2016-03-13
# 10 2014-04-08
# 11 2015-05-15
# 12 2013-10-30
# 13 2013-08-01
# 14 2016-07-15
# 15 2016-06-30
# 16 2016-08-25
# 17 2015-06-01
# 18 2015-10-29
# 19 2016-02-06
# 20 2018-01-04
# 21 2014-08-02
# 22 2014-11-09
# 23 2015-07-18
# 24 2017-06-22

# %%
matched_reviews = matched_reviews.merge(top_matched_reviews, on='review_id')

# %%
matched_reviews
# Out:
#     review_id  rating sentiment  vote  verified      reviewerID        asin  \
# 0      173319     3.0  negative   5.0      True  A1WT047CVF256C  B001LYPNFQ
# 1      112406     5.0  positive   0.0      True  A28GZ52326W7ET  B00139S3U6
# 2      352163     5.0  positive   0.0      True  A1LDB0HGS322GA  B005HPSFWI
# 3      227216     5.0  positive   0.0      True  A3NM39O6R8H3A5  B0039648BO
# 4      209586     5.0  positive  12.0     False  A25A7C826KIX2R  B002MT6SDU
# 5      222049     5.0  positive   0.0      True  A3376ZXV304DQV  B002ZVCGXQ
# 6      246770     5.0  positive   0.0      True  A37863TC1Q7059  B003Y3BJ7S
# 7      346497     4.0  positive  94.0     False  A2AY4YUOX2N1BQ  B005FNH9RE
# 8      473333     4.0  positive   0.0      True  A2GS7CV57Y7UT2  B0098Y77U0
# 9      473934     5.0  positive   0.0      True  A11Z60P0Z6CHFO  B0098Y77U0
# 10     594937     3.0  negative   2.0     False  A1F5YYNOS77MXM  B00CLZ047Q
# 11     568189     4.0  positive   6.0      True   ANXVC9YPIJBL4  B00BWBEL1U
# 12     567449     5.0  positive   7.0      True  A3F6KTX44THL5C  B00BV9AOL4
# 13     572342     4.0  positive  26.0      True   ATVW0VQARUDIG  B00C18YQ8Q
# 14    1248438     5.0  positive   5.0      True  A14UAWC9WEXD80  B01ERKL17E
# 15     713825     5.0  positive   0.0     False   AAFSO9JA44IAF  B00GTV05XG
# 16     736067     3.0  negative  38.0      True  A3DA8PZUYZ38RN  B00HY7PAUC
# 17     878360     4.0  positive   3.0     False   ASFW4ZMNZJKDA  B00NM76PXY
# 18    1033521     3.0  negative  18.0      True  A24ZGNMHCZPPAW  B00Y09G6JG
# 19    1118343     5.0  positive   9.0     False  A206M3IUN3N5IR  B015FP25V6
# 20    1128633     4.0  positive   0.0      True  A1P0TLLTHVTZNC  B015WCV70W
# 21     776932     4.0  positive   3.0      True  A38KK0SZYEH5UD  B00JR6GCZA
# 22     847415     5.0  positive   6.0     False   A6T1RHMQ9NSE4  B00M9B3XN4
# 23     983402     5.0  positive   2.0     False  A1UQUDT2Q0YENM  B00UGI1NGG
# 24    1204325     4.0  positive   6.0      True   A1FUO6JIIQZ5S  B01BV1X9DG
#
#                                                                                                                                                                                                  reviewText  \
# 0   Overall a nice monitor. Yes, it has tint problems out of the box, but you should calibrate every monitor you get anyway, regardless of quality. It can make a huge difference, even if you're not ed...
# 1   The latest generation of Hewlett Packard widescreen computer monitors sets a new standard for quality and value, and this model is probably just about right for your average desktop user. At 22inc...
# 2   I wanted to declutter my desk so I bought this stand to hold my 2 24 inch monitors. The price of the stand was good and it looks nice on my desk. The monitors are very stable. When mounting the mo...
# 3   I'm going to start this review of with what I feel are this monitors shortcomings, because there really aren't that many of them.\nAlso keep in mind that, my opinion of a pro or con, feature wise,...
# 4   I bought this to replace an older 4:3 Princeton LCD.  Worked fine right out of the box with my Lenovo T61 laptop and its built in NVidia graphics card.  My previous experience with 15-17" widescre...
# 5   This has to be the best monitor you can buy for the price.\n\nPros:\nPrice - for under two hundred, a bargain.\nQuality - the best monitor I've ever owned. No dead pixels, scratches, or anything. ...
# 6   Finally deciding to retire a 21" CRT Viewsonic mainly because it was making my computer room very hot in the summer.  I stayed with Viewsonic because of the positive experience I had for the past ...
# 7   *REVIEW UPDATED!*\n\nI recently built myself a desktop, so of course it was time for a new monitor. I knew I wanted LED for the power savings alone (and the arguably better blacks/contrast) and LG...
# 8   <div id="video-block-R9POUR97PUQWU" class="a-section a-spacing-small a-spacing-top-mini video-block"></div><input type="hidden" name="" value="https://images-na.ssl-images-amazon.com/images/I/D1yx...
# 9   I bought this monitor in early 2015 and I'm actually back to buy another for a dual monitor setup which brings me to this review I forgot to leave earlier. This monitor is great for my general pur...
# 10  i recently purchased the Best Buy version of this monitor (i2367F, which lacks HDMI input and internal speakers). I'll only comment on issues that should be common to both.  As others have said, t...
# 11  I've bought several of these monitors over the years, both for work and for home. Taking half a star off for the somewhat flimsy stand, but the monitor mounts to a swing arm without trouble. I lik...
# 12  Giving 4 stars because I've only had it 2 days.  Will revise later.  I've been considering this monitor for over a month but hesitated due to some of the negative reviews.  Mine was in perfect con...
# 13  I own several Samsung monitors and they are all great! The only real issue that appears to apply to all of them is the stand. They either completely lack adjustment capabilities or offer limited a...
# 14  It works. No problem out of the box. Ran it off my laptop for a couple hours and everything is up to scratch. No problems no dead pixels.\n\n The only thing I don't like is the TV noise it makes w...
# 15  We've been purchasing these monitors since they came out, and I have been impressed with their reliability and quality for the price. While they've seemingly been replaced by a newer model, the di...
# 16  So I was really worried about buying these monitors based on the reviews. However, they are absolutely the cheapest option to get both 144Hz and Freesync, so I bit the bullet and ordered 2.\n\nFir...
# 17  My teenage son was very interested in trying this out, and wrote the bulk of this review. (This is for the 22-inch model.)\n\nOur assessment is that this is a good monitor for the price. "A cheap ...
# 18  The concept of an ultrawide screen sounds good in theory, but in practice it has issues, and this monitor specifically misses the target.\n\nPROS:\n- great screen real estate, you can put three do...
# 19  <div id="video-block-R2UW8188LALIO0" class="a-section a-spacing-small a-spacing-top-mini video-block"></div><input type="hidden" name="" value="https://images-na.ssl-images-amazon.com/images/I/F1O...
# 20                I'm impressed with this monitor for the price. Good color and quality, with an impressive viewing angle. Simple to set up, too. Most significant drawback is the blacks aren't very dark.
# 21  I use the LG UM95 as a monitor for my circa 2012 Mac Book Pro and for an Intel NUC device running Linux. My aging eyes need all the real estate they can get. I was a bit concerned about the wait f...
# 22  Just like every product I've ever received from Dell, this monitor comes securely packaged to avoid any kind of damage upon arrival. This is always a huge plus for me, especially when dealing with...
# 23  There's nothing wrong with this monitor, but nothing amazing either. It does seem one step above other budget 24". It's a no-frills 24" monitor, but it looks good, feels solid, and has a three yea...
# 24  This is an excellent monitor for the price. I was in the market for a large monitor. I only wanted to have one big display, and the resolution of HDTVs was not crisp enough to read the text on the...
#
#                                                                                                                 reviewTitle  \
# 0                                                                                I would give 3.5 stars if it were possible
# 1                                                                                          HP Monitor Beats The Competition
# 2                                                                                        Good value, looks nice on the desk
# 3                                                                                       Best purchase I have made this year
# 4                                                                                                         Excellent Monitor
# 5                                                                                                             Great Product
# 6                                                                              Plenty of screen for photo, video and gaming
# 7                                                                                                For the price - excellent!
# 8                                                                                            Tilt difficult, NOT impossible
# 9                                                                                  A year later and still running like new!
# 10                                                                                      Good monitor if the price is right.
# 11                                         Serviceable secondary monitor. Base comes completely off. Not great in portrait.
# 12                                                                                                             Very Nice :)
# 13                                                                                          Good monitor, not so good stand
# 14                                                                        Top quality product model from samsung yet again.
# 15                                                                                  Good Mid-Range Monitor w/ Pros and Cons
# 16                                                              Just OK. Fine for budget, but if you can spend more, do it.
# 17                                                                                              Good monitor for the price.
# 18  Do your homework to make sure this is right for you - it has lots of problems that are not really discussed in reviews.
# 19                                                                                                         Awesome Product!
# 20                                                                                                      Great for the price
# 21                                                                                                                     Nice
# 22                                                                                              "Big Screen - Little Price"
# 23                                                          A bit better than most budget 24" monitors, but nothing amazing
# 24                                                                                        Excellent monitor for the price!!
#
#    reviewTime                           phrase  n_matches
# 0  2010-11-02  [the price, quality, the stand]          3
# 1  2008-12-20             [the price, quality]          2
# 2  2013-10-01           [the price, the stand]          2
# 3  2012-11-28  [the price, quality, the stand]          3
# 4  2009-12-29  [the price, quality, the stand]          3
# 5  2010-07-23  [the price, quality, the stand]          3
# 6  2013-01-31  [the price, quality, the stand]          3
# 7  2012-03-07  [the price, quality, the stand]          3
# 8  2016-10-05           [the price, the stand]          2
# 9  2016-03-13  [the price, quality, the stand]          3
# 10 2014-04-08  [the price, quality, the stand]          3
# 11 2015-05-15           [the price, the stand]          2
# 12 2013-10-30             [the price, quality]          2
# 13 2013-08-01  [the price, quality, the stand]          3
# 14 2016-07-15  [the price, quality, the stand]          3
# 15 2016-06-30  [the price, quality, the stand]          3
# 16 2016-08-25  [the price, quality, the stand]          3
# 17 2015-06-01  [the price, quality, the stand]          3
# 18 2015-10-29           [the price, the stand]          2
# 19 2016-02-06  [the price, quality, the stand]          3
# 20 2018-01-04             [the price, quality]          2
# 21 2014-08-02  [the price, quality, the stand]          3
# 22 2014-11-09  [the price, quality, the stand]          3
# 23 2015-07-18  [the price, quality, the stand]          3
# 24 2017-06-22           [the price, the stand]          2

# %% [markdown]
# # Getting product given attributes (and reviews)

# %%
review_results_query = \
    '''SELECT key_phrase_id, review_id 
        FROM key_phrase_reviews 
        WHERE key_phrase_id IN 
        (SELECT key_phrase_id 
        FROM key_phrase_root 
        WHERE phrase IN ('the price', 'the stand', '2 weeks', 'quality'))
    '''
review_ids_for_query = pd.read_sql(review_results_query, conn)

# %%
review_ids_for_query = review_ids_for_query.merge(query_phrases, on='key_phrase_id', how='left')
review_ids_for_query = review_ids_for_query.groupby('review_id')['phrase'].apply(list).reset_index()
review_ids_for_query['n_matches'] = review_ids_for_query['phrase'].apply(len)

# %%
review_ids_for_query.shape
# Out:
# (6870, 3)

# %%
fetch_matched_reviews_query = \
    f'''SELECT *
        FROM baseline_reviews
        WHERE review_id IN (
            {','.join(review_ids_for_query['review_id'].astype(str).tolist())}
        )
        
    '''
matched_reviews = pd.read_sql(fetch_matched_reviews_query, conn)

# %%
matched_reviews = matched_reviews.merge(review_ids_for_query, on='review_id')

# %%
matched_reviews.shape
# Out:
# (6870, 12)

# %%
matched_reviews.head()
# Out:
#    review_id  rating sentiment  vote  verified      reviewerID        asin  \
# 0      42179     5.0  positive  25.0      True  A24DGMBY82E69H  B0002X8TVW
# 1      54659     4.0  positive   0.0      True  A1A27N3E2A4PVT  B000A5S926
# 2      34776     5.0  positive  72.0     False  A1QJ8RKPWKXI7O  B00025EKO0
# 3      40298     5.0  positive   0.0      True   AERARUWRCEA3C  B0002M7FCC
# 4      40306     5.0  positive   0.0      True  A3IVIGQK3E3ZNT  B0002M7FCC
#
#                                                                                                                                                                                                 reviewText  \
# 0  I thought this monitor would be too good to be true for the price. It is fast, clear and I have not touched a control since getting it out of the box. It has been a joy to play video games on. Its...
# 1                                                                                                                                                                             Awesome sound for the price.
# 2  I'll echo the other comment. Educate yourself about the benefits and drawbacks of an LCD before opening trap. LCDs have one major limitation, and that is the image quality at anything other than n...
# 3                                                                                                 Awesome sub for the price. Now my movies and music have a nice hint of bass. Would highly recommend this
# 4                                                   works very nicely; easy to set up. Provides excellent bass for the price. It is a big larger than I expected though, be sure to review the dimensions.
#
#                                            reviewTitle reviewTime  \
# 0                                          Great Value 2005-03-02
# 1                         Awesome sound for the price. 2017-07-26
# 2  Make sure of your knowledge and needs before buying 2004-09-02
# 3                            Awesome sub for the price 2015-10-18
# 4                    works very nicely; easy to set up 2015-06-17
#
#         phrase  n_matches
# 0  [the price]          1
# 1  [the price]          1
# 2  [the price]          1
# 3  [the price]          1
# 4  [the price]          1

# %%
from collections import Counter

# %%
product_ranking = matched_reviews.groupby(['asin']).agg({
    'n_matches': 'sum',
    'rating': 'mean',
    'verified': 'sum',
    'vote': 'sum',
    'review_id': 'count',
    'phrase': 'sum'
}).sort_values(['review_id', 'rating', 'n_matches', 'verified',  'vote'], ascending=False).reset_index()

# %%
product_ranking.head()
# Out:
#          asin  n_matches    rating  verified    vote  review_id  \
# 0  B0098Y77U0        339  4.273616       288   322.0        307
# 1  B015WCV70W        226  4.539906       199   675.0        213
# 2  B003Y3BJ7S        159  4.544218       139  1188.0        147
# 3  B00EZSUWFG        131  4.336066       114   463.0        122
# 4  B00C8T5KOW        123  4.330435       106   143.0        115
#
#                                                                                                                                                                                                     phrase
# 0  [the price, the price, the stand, the price, the price, the price, the price, the price, quality, the stand, the price, the price, the price, the price, the stand, the price, quality, the price, q...
# 1  [the price, the price, the price, the price, the stand, the price, the stand, the price, the price, the price, the price, the price, the price, the price, the price, the price, the price, the pric...
# 2  [the stand, the price, the price, the price, quality, the price, the price, the price, the price, the price, quality, the price, the price, the price, the price, the price, the price, the price, q...
# 3  [the price, the price, the price, the stand, quality, the price, the price, the price, the price, the price, quality, the stand, the price, the price, the price, the price, the price, quality, the...
# 4  [the price, quality, the price, the price, the price, the price, the price, the price, the price, quality, the price, the stand, the price, the stand, the price, the price, the price, the price, t...

# %%
product_ranking['phrase'] = product_ranking['phrase'].apply(lambda x: Counter(x))

# %%
product_ranking = product_ranking.rename(columns={'review_id': 'n_reviews'})
product_ranking.head(10)
# Out:
#          asin  n_matches    rating  verified    vote  n_reviews  \
# 0  B0098Y77U0        339  4.273616       288   322.0        307
# 1  B015WCV70W        226  4.539906       199   675.0        213
# 2  B003Y3BJ7S        159  4.544218       139  1188.0        147
# 3  B00EZSUWFG        131  4.336066       114   463.0        122
# 4  B00C8T5KOW        123  4.330435       106   143.0        115
# 5  B00081NX5U        108  4.509434       100    86.0        106
# 6  B000A5S926        107  4.405660       100    85.0        106
# 7  B00CLZ047Q        118  4.298077        90   575.0        104
# 8  B00D601UC8        107  4.306931        94   584.0        101
# 9  B00IKDFL4O        101  4.593750        86   395.0         96
#
#                                                              phrase
# 0                {'the price': 232, 'the stand': 82, 'quality': 25}
# 1  {'the price': 162, 'the stand': 46, 'quality': 16, '2 weeks': 2}
# 2                {'the stand': 21, 'the price': 120, 'quality': 18}
# 3                 {'the price': 93, 'the stand': 25, 'quality': 13}
# 4                 {'the price': 95, 'quality': 12, 'the stand': 16}
# 5                                   {'the price': 99, 'quality': 9}
# 6                    {'the price': 94, 'quality': 12, '2 weeks': 1}
# 7   {'quality': 12, 'the price': 71, 'the stand': 34, '2 weeks': 1}
# 8                 {'the price': 73, 'the stand': 24, 'quality': 10}
# 9                  {'the price': 76, 'the stand': 19, 'quality': 6}

# %%
product_ranking.head(10).to_json(orient='records')
# Out:
# '[{"asin":"B0098Y77U0","n_matches":339,"rating":4.2736156352,"verified":288,"vote":322.0,"n_reviews":307,"phrase":{"the price":232,"the stand":82,"quality":25}},{"asin":"B015WCV70W","n_matches":226,"rating":4.5399061033,"verified":199,"vote":675.0,"n_reviews":213,"phrase":{"the price":162,"the stand":46,"quality":16,"2 weeks":2}},{"asin":"B003Y3BJ7S","n_matches":159,"rating":4.5442176871,"verified":139,"vote":1188.0,"n_reviews":147,"phrase":{"the stand":21,"the price":120,"quality":18}},{"asin":"B00EZSUWFG","n_matches":131,"rating":4.3360655738,"verified":114,"vote":463.0,"n_reviews":122,"phrase":{"the price":93,"the stand":25,"quality":13}},{"asin":"B00C8T5KOW","n_matches":123,"rating":4.3304347826,"verified":106,"vote":143.0,"n_reviews":115,"phrase":{"the price":95,"quality":12,"the stand":16}},{"asin":"B00081NX5U","n_matches":108,"rating":4.5094339623,"verified":100,"vote":86.0,"n_reviews":106,"phrase":{"the price":99,"quality":9}},{"asin":"B000A5S926","n_matches":107,"rating":4.4056603774,"verified":100,"vote":85.0,"n_reviews":106,"phrase":{"the price":94,"quality":12,"2 weeks":1}},{"asin":"B00CLZ047Q","n_matches":118,"rating":4.2980769231,"verified":90,"vote":575.0,"n_reviews":104,"phrase":{"quality":12,"the price":71,"the stand":34,"2 weeks":1}},{"asin":"B00D601UC8","n_matches":107,"rating":4.3069306931,"verified":94,"vote":584.0,"n_reviews":101,"phrase":{"the price":73,"the stand":24,"quality":10}},{"asin":"B00IKDFL4O","n_matches":101,"rating":4.59375,"verified":86,"vote":395.0,"n_reviews":96,"phrase":{"the price":76,"the stand":19,"quality":6}}]'

# %%
top10_products = product_ranking.head(10)

# %%
f'''
            '{"','".join(top10_products['asin'].astype(str).tolist())}'
    '''
# Out:
# "\n            'B0098Y77U0','B015WCV70W','B003Y3BJ7S','B00EZSUWFG','B00C8T5KOW','B00081NX5U','B000A5S926','B00CLZ047Q','B00D601UC8','B00IKDFL4O'\n    "

# %%
fetch_matched_products_query = \
    f'''SELECT *
        FROM baseline_products
        WHERE asin IN ('{"','".join(top10_products['asin'].astype(str).tolist())}')
    '''
matched_products = pd.read_sql(fetch_matched_products_query, conn)

# %%
matched_products.shape
# Out:
# (10, 13)

# %%
top10_products = top10_products.merge(matched_products[['asin', 'title', 'description', 'imageURLHighRes']], on='asin')

# %%
top10_products
# Out:
#          asin  n_matches    rating  verified    vote  n_reviews  \
# 0  B0098Y77U0        339  4.273616       288   322.0        307
# 1  B015WCV70W        226  4.539906       199   675.0        213
# 2  B003Y3BJ7S        159  4.544218       139  1188.0        147
# 3  B00EZSUWFG        131  4.336066       114   463.0        122
# 4  B00C8T5KOW        123  4.330435       106   143.0        115
# 5  B00081NX5U        108  4.509434       100    86.0        106
# 6  B000A5S926        107  4.405660       100    85.0        106
# 7  B00CLZ047Q        118  4.298077        90   575.0        104
# 8  B00D601UC8        107  4.306931        94   584.0        101
# 9  B00IKDFL4O        101  4.593750        86   395.0         96
#
#                                                              phrase  \
# 0                {'the price': 232, 'the stand': 82, 'quality': 25}
# 1  {'the price': 162, 'the stand': 46, 'quality': 16, '2 weeks': 2}
# 2                {'the stand': 21, 'the price': 120, 'quality': 18}
# 3                 {'the price': 93, 'the stand': 25, 'quality': 13}
# 4                 {'the price': 95, 'quality': 12, 'the stand': 16}
# 5                                   {'the price': 99, 'quality': 9}
# 6                    {'the price': 94, 'quality': 12, '2 weeks': 1}
# 7   {'quality': 12, 'the price': 71, 'the stand': 34, '2 weeks': 1}
# 8                 {'the price': 73, 'the stand': 24, 'quality': 10}
# 9                  {'the price': 76, 'the stand': 19, 'quality': 6}
#
#                                                                                                                                                                                 title  \
# 0                                                                                                                                      Acer G236HL Bbd 23-Inch Screen LED-Lit Monitor
# 1                                                                                                                              HP Pavilion 21.5-Inch IPS LED HDMI VGA Monitor (22cwa)
# 2                                                                 ViewSonic VX2250WM-LED 22-Inch (21.5-Inch Vis) Widescreen Full HD 1080p LED Monitor with Integrated Stereo Speakers
# 3                                                                                               ViewSonic VX2252MH 22 Inch 2ms 75Hz 1080p Gaming Monitor with HDMI DVI and VGA Inputs
# 4                                                                     AOC e2050Swd 20-Inch Class Screen LED-Lit Computer Monitor, 1600 x 900 Resolution, 5ms, 20M:1DCR, VGA/DVI, VESA
# 5                       Dual Electronics LU43PB 4 inch 3-Way High Performance Indoor, Outdoor &amp; Bookshelf Studio Monitor Speakers with Swivel Brackets &amp; 100 Watts Peak Power
# 6       Dual Electronics LU43PW 4 inch 3-Way High Performance Indoor, Outdoor &amp; Bookshelf Studio Monitor Speakers with Swivel Brackets &amp; 100 Watts Peak Power (Sold in Pairs)
# 7                                                                        AOC I2267FW 22-Inch Class IPS Frameless/Slim LED Monitor, Full HD,250 cd/m2 Brightness,5ms,50M:1 DCR,VGA/DVI
# 8                                                                                                     ViewSonic VA2446M-LED 24 Inch Full HD 1080p LED Monitor with DVI and VGA Inputs
# 9  BenQ GL2460HM 24 Inch 1080p LED Gaming Monitor, 2ms, HDMI, DVI, Built-In Speakers, Eye Care Technology, Low Blue Light, ZeroFlicker, Energy Star Certified Monitor, VESA mountable
#
#                                                                                                                                                                                                description  \
# 0  Acer G-Series monitors sport a super-slim profile with an X-shaped stand that lets them fit nicely in spaces of any size. Oustanding performance, eco-friendliness and smart use of energy complemen...
# 1  It's time for a monitor that's worthy of your family's content. When you're looking for the best specs at the right price, the 21.5" diagonal full HD display delivers with trusted HP performance a...
# 2  ViewSonic&#8217;s VX2250wm-LED features an LED backlight 22-Inch (21.5-Inch Vis) widescreen monitor with up to 40% energy saving compared to a regular 22-Inch monitor. mercury free VX2250wm-LED of...
# 3  ViewSonic's VX2252mh is a 22" (21.5" viewable) 60Hz Full HD, glossy-finish display that offers the ultimate visual experience for gaming and multimedia entertainment. The VX2252mh features ClearMo...
# 4                                                                                  AOC e2050Swd 19. 5" Hd 1600x900 monitor, 5ms, DVI-D/VGA, VESA compatible, low power mode, EPEAT silver, energy start or
# 5  The Dual Electronics LU43PB 4 inch 3-Way High Performance Indoor, Outdoor &amp; Bookshelf Studio Monitor Speakers with Swivel Brackets &amp; 100 Watts Peak Power will make a great addition to any ...
# 6  The Dual Electronics LU43PW 4 inch 3-Way High Performance Indoor, Outdoor & Bookshelf Studio Monitor Speakers with Swivel Brackets & 100 Watts Peak Power will make a great addition to any home. Yo...
# 7  Display your work and entertainment with a nearly borderless appearance thanks to the ultra-narrow bezel. Enjoy brilliant color reproduction and impressive 178-degree viewing angles with IPS techn...
# 8  The ViewSonic VA2446m-LED is a 24" (23.6 Vis) widescreen monitor with an LED backlight and glossy, thin-bezel design ideal for use in the home or at the office. With Full HD 1920x1080 resolution a...
# 9                                                                                                                                                                          BENQ GL2460HM 24 Gaming Monitor
#
#                                                                                                                                                                                            imageURLHighRes
# 0  https://images-na.ssl-images-amazon.com/images/I/31Nq2Q4eMSL.jpg, https://images-na.ssl-images-amazon.com/images/I/31Oq-Fq7z2L.jpg, https://images-na.ssl-images-amazon.com/images/I/31%2B5p99yQTL.j...
# 1  https://images-na.ssl-images-amazon.com/images/I/51ede3cxIDL.jpg, https://images-na.ssl-images-amazon.com/images/I/41F%2Bgneo-HL.jpg, https://images-na.ssl-images-amazon.com/images/I/511uOc7mRfL.j...
# 2  https://images-na.ssl-images-amazon.com/images/I/51MGz38raAL.jpg, https://images-na.ssl-images-amazon.com/images/I/51jjG6kBQcL.jpg, https://images-na.ssl-images-amazon.com/images/I/31uiD74sUvL.jpg...
# 3  https://images-na.ssl-images-amazon.com/images/I/512yOFwUspL.jpg, https://images-na.ssl-images-amazon.com/images/I/41cnUNS3tqL.jpg, https://images-na.ssl-images-amazon.com/images/I/41laWQIDoQL.jpg...
# 4  https://images-na.ssl-images-amazon.com/images/I/213uchzTA0L.jpg, https://images-na.ssl-images-amazon.com/images/I/41EKKgnJYrL.jpg, https://images-na.ssl-images-amazon.com/images/I/511LSTbBIwL.jpg...
# 5  https://images-na.ssl-images-amazon.com/images/I/51GQZT32D9L.jpg, https://images-na.ssl-images-amazon.com/images/I/51iHCQI7OVL.jpg, https://images-na.ssl-images-amazon.com/images/I/51jEBRfGxRL.jpg...
# 6  https://images-na.ssl-images-amazon.com/images/I/51DaTB-QoUL.jpg, https://images-na.ssl-images-amazon.com/images/I/51EN9ki4oGL.jpg, https://images-na.ssl-images-amazon.com/images/I/518JmpJWBoL.jpg...
# 7  https://images-na.ssl-images-amazon.com/images/I/31UdbNgrvIL.jpg, https://images-na.ssl-images-amazon.com/images/I/31BjjEDvgvL.jpg, https://images-na.ssl-images-amazon.com/images/I/41eVcOM-tDL.jpg...
# 8  https://images-na.ssl-images-amazon.com/images/I/518mJ7vMY%2BL.jpg, https://images-na.ssl-images-amazon.com/images/I/41LJZ%2BBTBcL.jpg, https://images-na.ssl-images-amazon.com/images/I/419qPc643zL...
# 9                                                                       https://images-na.ssl-images-amazon.com/images/I/41fUr0x8tCL.jpg, https://images-na.ssl-images-amazon.com/images/I/51bqA7ibEYL.jpg

# %%
top10_products.to_json(orient='records').replace('\\/', '/')
# Out:
# '[{"asin":"B0098Y77U0","n_matches":339,"rating":4.2736156352,"verified":288,"vote":322.0,"n_reviews":307,"phrase":{"the price":232,"the stand":82,"quality":25},"title":"Acer G236HL Bbd 23-Inch Screen LED-Lit Monitor","description":"Acer G-Series monitors sport a super-slim profile with an X-shaped stand that lets them fit nicely in spaces of any size. Oustanding performance, eco-friendliness and smart use of energy complement the sleek design - all while staying well within budget. The Acer G236HL Bbd showcases a 23\\" Widescreen LCD with impressive 1920 x 1080 resolution. Enjoy widely available 16:9 HD digital content without image distortion on the expansive widescreen LCD. The remarkable 100 Million:1 contrast ratio ensures a crystal-clear viewing experience while rapid 5ms response time keeps moving images sharp. It also supports both VGA and DVI-D inputs offering greater compatibility. The Acer G-Series LCD brings an amazing multimedia experience to your home with a widescreen cinematic view and a unique fighter pilot style.","imageURLHighRes":"https://images-na.ssl-images-amazon.com/images/I/31Nq2Q4eMSL.jpg, https://images-na.ssl-images-amazon.com/images/I/31Oq-Fq7z2L.jpg, https://images-na.ssl-images-amazon.com/images/I/31%2B5p99yQTL.jpg, https://images-na.ssl-images-amazon.com/images/I/31tdPiLtz6L.jpg"},{"asin":"B015WCV70W","n_matches":226,"rating":4.5399061033,"verified":199,"vote":675.0,"n_reviews":213,"phrase":{"the price":162,"the stand":46,"quality":16,"2 weeks":2},"title":"HP Pavilion 21.5-Inch IPS LED HDMI VGA Monitor (22cwa)","description":"It\'s time for a monitor that\'s worthy of your family\'s content. When you\'re looking for the best specs at the right price, the 21.5\\" diagonal full HD display delivers with trusted HP performance and an all new sleek design.","imageURLHighRes":"https://images-na.ssl-images-amazon.com/images/I/51ede3cxIDL.jpg, https://images-na.ssl-images-amazon.com/images/I/41F%2Bgneo-HL.jpg, https://images-na.ssl-images-amazon.com/images/I/511uOc7mRfL.jpg, https://images-na.ssl-images-amazon.com/images/I/51IX0mi0zoL.jpg, https://images-na.ssl-images-amazon.com/images/I/41LHZIP%2BlDL.jpg"},{"asin":"B003Y3BJ7S","n_matches":159,"rating":4.5442176871,"verified":139,"vote":1188.0,"n_reviews":147,"phrase":{"the stand":21,"the price":120,"quality":18},"title":"ViewSonic VX2250WM-LED 22-Inch (21.5-Inch Vis) Widescreen Full HD 1080p LED Monitor with Integrated Stereo Speakers","description":"ViewSonic&#8217;s VX2250wm-LED features an LED backlight 22-Inch (21.5-Inch Vis) widescreen monitor with up to 40% energy saving compared to a regular 22-Inch monitor. mercury free VX2250wm-LED offers a Full HD 1920x1080 resolution, 5ms response time, 10,000,000:1 MEGA Dynamic Contrast Ratio, digital and analog inputs and integrated stereo speakers. Ideal for both home and office with the piano black finish, VX2250wm-LED can be mounted on a VESA compliant stand or wall mount bracket. It also has an automatic aspect ratio adjustment so when your input is a 4:3 signal, the image will not be stretched but instead it will be positioned in the middle of the screen with side bars. 3 year warranty, industry&#8217;s best pixel performance policy and Windows 7 certification make VX2250wm-LED a great long term investment. , incredible picture quality. ViewSonic&rsquo;s VX2250wm-LED features a mercury free LED backlight 22&rdquo; (21.5&rdquo; Vis) widescreen display with up to 40% energy savings compared to traditional CCFL backlit LCD monitors. The VX2250wm-LED offers Full HD 1920x1080 resolution, 5ms response time, an incredible 10,000,000:1 MEGA Dynamic Contrast Ratio, digital and analog inputs and integrated stereo speakers. Ideal for both the home and office with its piano black finish, the VX2250wm-LED is an elegant fit to any d&eacute;cor. Should you choose to mount the display, it can be mounted on a VESA compliant stand or wall mount bracket. Another great feature is the display&rsquo;s automatic aspect ratio ...

# %% [markdown]
# # Scratch

# %%
review_ids_for_query['review_id'].value_counts().head(20)
# Out:
# 776932     3
# 227216     3
# 209586     3
# 222049     3
# 246770     3
# 1118343    3
# 1248438    3
# 847415     3
# 983402     3
# 572342     3
# 346497     3
# 878360     3
# 473934     3
# 594937     3
# 173319     3
# 736067     3
# 713825     3
# 898932     2
# 117150     2
# 488534     2
# Name: review_id, dtype: int64
