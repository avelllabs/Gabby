# %% [markdown]
# # In this notebook
#
# - We build API functions that return the newer shortlisted attributes
# - We refer to notebooks `13`, `14`, `16`, and `17` as needed.

# %%
import pandas as pd
import json

pd.options.display.max_columns = 50
pd.options.display.max_colwidth = 200
pd.options.display.max_rows = 1000

# %%
from sqlalchemy import create_engine
import psycopg2 
import io

# %%
import os
import glob

# %%
import pickle

# %%
import numpy as np

# %% [markdown]
# ### set up database connection

# %%
conn_string = 'postgresql+psycopg2://gabbydbuser:gabbyDBpass@localhost:5432/gabbyDB'

# %%
db = create_engine(conn_string)
conn = db.connect()

# %%
CATEGORY = 'headphone'

# %% [markdown]
# # get_attributes_list() API

# %%
def get_attributes_list(category, n_qphrase_attrs=10):
    shortlisted_attributes_query = \
        f'''
        SELECT *
        FROM shortlisted_attributes
        WHERE category='{category}'
        '''
    shortlisted_attributes = pd.read_sql(shortlisted_attributes_query, conn)
    sim_attrs_list = \
        shortlisted_attributes. \
            sort_values('neighbor_distances').sort_values('n_reviews', ascending=False). \
                groupby('qphrase'). \
                    head(n_qphrase_attrs). \
                        reset_index(drop=True)[['key_phrase_id', 'phrase', 'qphrase']].sort_values('qphrase')
    sim_attrs_list_deduped =  sim_attrs_list[['key_phrase_id', 'phrase']].drop_duplicates()
    return sim_attrs_list_deduped.sample(min(50, sim_attrs_list.shape[0]))

# %%
get_attributes_list(CATEGORY, 5)
# Out:
# 39
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb#Y161sZmlsZQ%3D%3D?line=0'>1</a> get_attributes_list(CATEGORY, 5)
#
# /Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb Cell 13 in get_attributes_list(category, n_qphrase_attrs)
#       <a href='vscode-notebook-cell:/Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb#Y161sZmlsZQ%3D%3D?line=8'>9</a> sim_attrs_list = \
#      <a href='vscode-notebook-cell:/Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb#Y161sZmlsZQ%3D%3D?line=9'>10</a>     shortlisted_attributes. \
#      <a href='vscode-notebook-cell:/Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb#Y161sZmlsZQ%3D%3D?line=10'>11</a>         sort_values('neighbor_distances').sort_values('n_reviews', ascending=False). \
#      <a href='vscode-notebook-cell:/Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb#Y161sZmlsZQ%3D%3D?line=11'>12</a>             groupby('qphrase'). \
#      <a href='vscode-notebook-cell:/Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb#Y161sZmlsZQ%3D%3D?line=12'>13</a>                 head(n_qphrase_attrs). \
#      <a href='vscode-notebook-cell:/Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb#Y161sZmlsZQ%3D%3D?line=13'>14</a>                     reset_index(drop=True)[['key_phrase_id', 'phrase', 'qphrase']].sort_values('qphrase')
#      <a href='vscode-notebook-cell:/Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb#Y161sZmlsZQ%3D%3D?line=14'>15</a> print(min(50, sim_attrs_list.shape[0]))
# ---> <a href='vscode-notebook-cell:/Users/nimblenotions/Experiments/GetGabby/notebooks/18_gb_API_functions_new_version.ipynb#Y161sZmlsZQ%3D%3D?line=15'>16</a> return sim_attrs_list[['key_phrase_id', 'phrase']].drop_duplicates().sample(min(50, sim_attrs_list.shape[0]))
#
# File ~/opt/anaconda3/envs/gabby-env/lib/python3.10/site-packages/pandas/core/generic.py:5778, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5775 if weights is not None:
#    5776     weights = sample.preprocess_weights(self, weights, axis)
# -> 5778 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5779 result = self.take(sampled_indices, axis=axis)
#    5781 if ignore_index:
#
# File ~/opt/anaconda3/envs/gabby-env/lib/python3.10/site-packages/pandas/core/sample.py:150, in sample(obj_len, size, replace, weights, random_state)
#     147     else:
#     148         raise ValueError("Invalid weights: weights sum to zero")
# --> 150 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     151     np.intp, copy=False
#     152 )
#
# File mtrand.pyx:965, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %% [markdown]
# # Scratch

# %%
shortlisted_attributes_query = \
    f'''
    SELECT *
    FROM shortlisted_attributes
    WHERE category='{CATEGORY}'
    '''
shortlisted_attributes = pd.read_sql(shortlisted_attributes_query, conn)

# %%
shortlisted_attributes.shape
# Out:
# (386, 12)

# %%
sim_attrs_list = shortlisted_attributes.sort_values('neighbor_distances').sort_values('n_reviews', ascending=False).groupby('qphrase').head(10).reset_index(drop=True)[['key_phrase_id', 'phrase', 'qphrase']].sort_values('qphrase')
sim_attrs_list
# Out:
#     key_phrase_id                     phrase                     qphrase
# 33         331141                  nice bass                awesome bass
# 15         328427                  good bass                awesome bass
# 61         331635          great punchy bass                awesome bass
# 60         330317                  mild bass                awesome bass
# 49         333649                decent bass                awesome bass
# 48         328397                   big bass                awesome bass
# 29         328918                strong bass                awesome bass
# 12         328681                 great bass                awesome bass
# 34         331766                 heavy bass                awesome bass
# 62         333517              blissful bass                awesome bass
# 30         329669               volume level                battery life
# 31         329045            quality product                battery life
# 7          328974                price range                battery life
# 6          329047             volume control                battery life
# 1          329058               battery life                battery life
# 27         332900         good quality sound             comfortable fit
# 26         332494                   good fit             comfortable fit
# 23         331978        great audio quality             comfortable fit
# 21         328993         poor sound quality             comfortable fit
# 0          328250                 good sound             comfortable fit
# 9          328744    excellent sound quality             comfortable fit
# 18         328479      amazing sound quality             comfortable fit
# 3          328821         good sound quality             comfortable fit
# 16         329203            comfortable fit             comfortable fit
# 4          328308        great sound quality             comfortable fit
# 43         331595     great customer support  effective noise cancelling
# 47         333581        decent battery life  effective noise cancelling
# 40         332545    active noise cancelling  effective noise cancelling
# 37         333151    good noise cancellation  effective noise cancelling
# 36         332935  active noise cancellation  effective noise cancelling
# 45         330730      good noise cancelling  effective noise cancelling
# 32         330168     great noise cancelling  effective noise cancelling
# 41         331711       good noise isolation  effective noise cancelling
# 10         332508          good battery life  effective noise cancelling
# 46         328990   great sound reproduction  effective noise cancelling
# 11         329784                  great fit                    good fit
# 50         332770              excellent fit                    good fit
# 53         331507                    bad fit                    good fit
# 57         335321    comfortable fit battery                    good fit
# 14         329203            comfortable fit                    good fit
# 39         329197                   nice fit                    good fit
# 59         332288                    new fit                    good fit
# 24         332494                   good fit                    good fit
# 42         331315                   poor fit                    good fit
# 44         331175                  tight fit                    good fit
# 5          328308        great sound quality          good sound quality
# 2          328821         good sound quality          good sound quality
# 20         328993         poor sound quality          good sound quality
# 38         329211         good audio quality          good sound quality
# 35         329084       decent sound quality          good sound quality
# 8          328744    excellent sound quality          good sound quality
# 28         329043         high quality sound          good sound quality
# 25         332900         good quality sound          good sound quality
# 17         328479      amazing sound quality          good sound quality
# 22         331978        great audio quality          good sound quality
# 52         332527                 works good                  is durable
# 13         329758                works great                  is durable
# 54         336085                sounds good                  is durable
# 58         333230           sounds excellent                  is durable
# 63         331401                 gels tight                  is durable
# 51         331166                light usage                light Weight
# 55         332549          light weight easy                light Weight
# 56         333974                light music                light Weight
# 19         328258               light weight                light Weight

# %%
sim_attrs_list[['key_phrase_id', 'phrase']].drop_duplicates().sample(50)
# Out:
#     key_phrase_id                     phrase
# 31         329045            quality product
# 15         328427                  good bass
# 0          328250                 good sound
# 12         328681                 great bass
# 32         330168     great noise cancelling
# 36         332935  active noise cancellation
# 3          328821         good sound quality
# 39         329197                   nice fit
# 16         329203            comfortable fit
# 7          328974                price range
# 19         328258               light weight
# 45         330730      good noise cancelling
# 48         328397                   big bass
# 6          329047             volume control
# 60         330317                  mild bass
# 52         332527                 works good
# 40         332545    active noise cancelling
# 30         329669               volume level
# 61         331635          great punchy bass
# 41         331711       good noise isolation
# 49         333649                decent bass
# 26         332494                   good fit
# 46         328990   great sound reproduction
# 42         331315                   poor fit
# 58         333230           sounds excellent
# 51         331166                light usage
# 55         332549          light weight easy
# 9          328744    excellent sound quality
# 54         336085                sounds good
# 37         333151    good noise cancellation
# 21         328993         poor sound quality
# 23         331978        great audio quality
# 28         329043         high quality sound
# 35         329084       decent sound quality
# 63         331401                 gels tight
# 57         335321    comfortable fit battery
# 44         331175                  tight fit
# 29         328918                strong bass
# 13         329758                works great
# 59         332288                    new fit
# 56         333974                light music
# 10         332508          good battery life
# 43         331595     great customer support
# 50         332770              excellent fit
# 47         333581        decent battery life
# 11         329784                  great fit
# 1          329058               battery life
# 4          328308        great sound quality
# 38         329211         good audio quality
# 34         331766                 heavy bass

# %%
sim_attr_lists['n_attrs'] = sim_attr_lists['phrase'].apply(lambda x: len(x))

# %%
#shortlisted_attributes.sort_values('n_reviews', ascending=False).sort_values('neighbor_distances').groupby('qphrase')['phrase'].apply(list).reset_index()

# %%
sim_attr_lists
# Out:
#                       qphrase  \
# 0                awesome bass
# 1                battery life
# 2             comfortable fit
# 3  effective noise cancelling
# 4                    good fit
# 5          good sound quality
# 6                  is durable
# 7                light Weight
#
#                                                                                                                                                                                                     phrase  \
# 0  [great bass, good bass, strong bass, nice bass, heavy bass, big bass, decent bass, mild bass, great punchy bass, blissful bass, great bass response, great bass performance, great bass sound, reaso...
# 1                                                                                                                               [battery life, volume control, price range, volume level, quality product]
# 2  [good sound, good sound quality, great sound quality, excellent sound quality, comfortable fit, amazing sound quality, poor sound quality, great audio quality, good fit, good quality sound, high q...
# 3  [good battery life, great noise cancelling, active noise cancellation, good noise cancellation, active noise cancelling, good noise isolation, great customer support, good noise cancelling, great ...
# 4                                                              [great fit, comfortable fit, good fit, nice fit, poor fit, tight fit, excellent fit, bad fit, comfortable fit battery, new fit, decent fit]
# 5  [good sound quality, great sound quality, excellent sound quality, amazing sound quality, poor sound quality, great audio quality, good quality sound, high quality sound, decent sound quality, goo...
# 6                                                                                                                                     [works great, works good, sounds good, sounds excellent, gels tight]
# 7                                                                                                                                              [light weight, light usage, light weight easy, light music]
#
#    n_attrs
# 0       15
# 1        5
# 2      122
# 3      124
# 4       11
# 5      100
# 6        5
# 7        4
